# %%
import os
import csv
import cv2
import dlib
import numpy as np
import pandas as pd

from scipy.spatial.distance import pdist, squareform
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from dlib import get_frontal_face_detector, shape_predictor
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score, mean_absolute_error

# %%
image_start = 1
image_end = 1200

# %%
# 사진 검색 후 얼굴 추출

# dlib 검출기와 예측기 초기화
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat")

image_start = 1
image_end = 1200

# 이미지에 대해 반복
for i in range(image_start, image_end+1):
    image_path = f"IMAGE/{i}.jpg"


    if os.path.exists(image_path):
        image = cv2.imread(image_path)
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    else:
        print(f"Error: No face detected in the image face_{i}.")
        continue

    faces = detector(gray)

    for j, face in enumerate(faces):
        landmarks = predictor(gray, face)
        landmarks = np.array([(landmarks.part(i).x, landmarks.part(i).y) for i in range(68)])

        x, y, w, h = face.left(), face.top(), face.width(), face.height()
        cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)

        for (x, y) in landmarks:
            cv2.circle(image, (x, y), 1, (0, 0, 255), -1)

        distances = pdist(landmarks)
        distance_matrix = squareform(distances)

        with open(f"landmark_distances/landmark_distances({i}).csv", "w", newline="") as csvfile2:
            writer2 = csv.writer(csvfile2)
            header = ["Landmark"] + [str(i) for i in range(1, 69)]
            writer2.writerow(header)
            writer2.writerows((i+1, *[f"{d:.8f}" for d in row]) for i, row in enumerate(distance_matrix))

print(f"Processing of {i} images completed.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 22
#      19     print(f"Error: No face detected in the image face_{i}.")
#      20     continue
# ---> 22 faces = detector(gray)
#      24 for j, face in enumerate(faces):
#      25     landmarks = predictor(gray, face)
#
# KeyboardInterrupt:

# %%
# 최적의 i_val구하기

min_mse = float("inf")
min_mae = float("inf")
max_r2 = float(0)
min_file_number = None
min_i = None

file_numbers = range(image_start, image_end+1)
i_values = range(1, 100)
for i_val in i_values:
    for file_number in range(image_start, image_end + 1):
        distances_file = f"landmark_distances/landmark_distances({file_number}).csv"
        
        if not os.path.exists(distances_file):
            continue
        data = pd.read_csv(distances_file)
        
        # 특징과 라벨 분리
        X = data.drop(columns=["Landmark"])
        y = data["Landmark"]

        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=i_val)


        # 선형 회귀 모델 생성 및 훈련
        model = LinearRegression()
        model.fit(X_train, y_train)

        # 검증 데이터를 사용하여 성능평가: 예측
        test_predictions = model.predict(X_test)

        # R-squared 계산
        r2 = r2_score(y_test, test_predictions)
        
        # 평균 제곱 오차(MSE) 계산
        mse = mean_squared_error(y_test, test_predictions)
        
        # 평균 절대 오차(MAE) 계산
        mae = mean_absolute_error(y_test, test_predictions)
        
        if mse < min_mse and mae < min_mae and r2 > max_r2:
            min_mse = mse
            min_mae = mae
            max_r2 = r2
            min_i = i_val
            min_file_number = file_number

# %%
# 결과 출력
print(f"가장 작은 MSE: {min_mse}")
print(f"가장 작은 MAE: {min_mae}")
print(f"가장 큰 R-squared: {max_r2}")
print(f"최소 MSE에 해당하는 i 값: {min_i}")
print(f"가장 작은 MSE에 해당하는 파일 번호: {min_file_number}")
# Out:
# 가장 작은 MSE: 0.04259587124337109
# 가장 작은 MAE: 0.17443148525575122
# 가장 큰 R-squared: 0.9999205603375609
# 최소 MSE에 해당하는 i 값: 75
# 가장 작은 MSE에 해당하는 파일 번호: 241

# %%
# 구한 최적의 i값으로 다시 학습

new_min_mse = float("inf")
new_min_mae = float("inf")
new_max_r2 = float(0)
new_min_file_number = None
new_min_i = None

file_numbers = range(image_start, image_end+1)

# 각 파일 번호에 대해 처리를 반복합니다.
for file_number in file_numbers:
    distances_file = f"landmark_distances/landmark_distances({file_number}).csv"

    if not os.path.exists(distances_file):
        continue

    data = pd.read_csv(distances_file)

    X = data.drop(columns=["Landmark"])
    y = data["Landmark"]

    # 최적의 i 값을 사용하여 데이터를 분할합니다.
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=min_i)

    model = LinearRegression()
    model.fit(X_train, y_train)
    test_predictions = model.predict(X_test)

    # R-squared 계산
    new_r2 = r2_score(y_test, test_predictions)
    
    # 평균 제곱 오차(MSE) 계산
    new_mse = mean_squared_error(y_test, test_predictions)
    
    # 평균 절대 오차(MAE) 계산
    new_mae = mean_absolute_error(y_test, test_predictions)
    
    # 각 파일에 대한 MSE를 찾아 가장 작은 MSE를 찾고 파일 번호를 업데이트합니다.
    if new_mse < new_min_mse and new_mae < new_min_mae and new_r2 > new_max_r2:
        new_min_mse = new_mse
        new_min_mae = new_mae
        new_max_r2 = new_r2        
        new_min_file_number = file_number

    # 각 파일에 대한 평균 제곱 오차 출력
    print(f"{file_number}의 평균 제곱 오차: {new_mse:.4f}")
    print(f"{file_number}의 평균 절대 오차: {new_mae:.4f}")
    print(f"{file_number}의 R-squared: {new_r2:.4f}")
# Out:
# 4의 평균 제곱 오차: 3.0445
# 4의 평균 절대 오차: 1.1698
# 4의 R-squared: 0.9943
# 5의 평균 제곱 오차: 2.6007
# 5의 평균 절대 오차: 1.0157
# 5의 R-squared: 0.9951
# 20의 평균 제곱 오차: 4.9246
# 20의 평균 절대 오차: 1.4172
# 20의 R-squared: 0.9908
# 21의 평균 제곱 오차: 4.1307
# 21의 평균 절대 오차: 1.3449
# 21의 R-squared: 0.9923
# 22의 평균 제곱 오차: 2.9657
# 22의 평균 절대 오차: 0.9784
# 22의 R-squared: 0.9945
# 23의 평균 제곱 오차: 3.5795
# 23의 평균 절대 오차: 1.1530
# 23의 R-squared: 0.9933
# 24의 평균 제곱 오차: 3.9833
# 24의 평균 절대 오차: 1.2426
# 24의 R-squared: 0.9926
# 25의 평균 제곱 오차: 2.5310
# 25의 평균 절대 오차: 0.9481
# 25의 R-squared: 0.9953
# 26의 평균 제곱 오차: 2.5837
# 26의 평균 절대 오차: 1.0091
# 26의 R-squared: 0.9952
# 27의 평균 제곱 오차: 3.5259
# 27의 평균 절대 오차: 1.2590
# 27의 R-squared: 0.9934
# 28의 평균 제곱 오차: 2.1200
# 28의 평균 절대 오차: 0.9892
# 28의 R-squared: 0.9960
# 29의 평균 제곱 오차: 2.8942
# 29의 평균 절대 오차: 1.1999
# 29의 R-squared: 0.9946
# 30의 평균 제곱 오차: 3.7984
# 30의 평균 절대 오차: 1.2378
# 30의 R-squared: 0.9929
# 31의 평균 제곱 오차: 2.9362
# 31의 평균 절대 오차: 1.1270
# 31의 R-squared: 0.9945
# 32의 평균 제곱 오차: 2.0669
# 32의 평균 절대 오차: 1.0504
# 32의 R-squared: 0.9961
# 33의 평균 제곱 오차: 2.7173
# 33의 평균 절대 오차: 0.9798
# 33의 R-squared: 0.9949
# 34의 평균 제곱 오차: 1.8622
# 34의 평균 절대 오차: 0.9181
# 34의 R-squared: 0.9965
# 35의 평균 제곱 오차: 2.2589
# 35의 평균 절대 오차: 0.9280
# 35의 R-squared: 0.9958
# 36의 평균 제곱 오차: 3.6736
# 36의 평균 절대 오차: 1.1514
# 36의 R-squared: 0.9931
# 37의 평균 제곱 오차: 1.9560
# 37의 평균 절대 오차: 0.8860
# 37의 R-squared: 0.9964
# 38의 평균 제곱 오차: 1.2032
# 38의 평균 절대 오차: 0.7897
# 38의 R-squared: 0.9978
# 40의 평균 제곱 오차: 1.8052
# 40의 평균 절대 오차: 1.0191
# 40의 R-squared: 0.9966
# 41의 평균 제곱 오차: 0.7401
# 41의 평균 절대 오차: 0.7290
# 41의 R-squared: 0.9986
# 42의 평균 제곱 오차: 2.0745
# 42의 평균 절대 오차: 1.0257
# 42의 R-squared: 0.9961
# 43의 평균 제곱 오차: 1.4224
# 43의 평균 절대 오차: 0.9723
# 43의 R-squared: 0.9973
# 44의 평균 제곱 오차: 3.9311
# 44의 평균 절대 오차: 1.2986
# 44의 R-squared: 0.9927
# 45의 평균 제곱 오차: 1.9367
# 45의 평균 절대 오차: 1.0906
# 45의 R-squared: 0.9964
# 46의 평균 제곱 오차: 1.9994
# 46의 평균 절대 오차: 1.0973
# 46의 R-squared: 0.9963
# 47의 평균 제곱 오차: 1.9528
# 47의 평균 절대 오차: 1.0352
# 47의 R-squared: 0.9964
# 48의 평균 제곱 오차: 3.7711
# 48의 평균 절대 오차: 1.3636
# 48의 R-squared: 0.9930
# 49의 평균 제곱 오차: 2.4897
# 49의 평균 절대 오차: 0.9770
# 49의 R-squared: 0.9954
# 50의 평균 제곱 오차: 2.7115
# 50의 평균 절대 오차: 1.0715
# 50의 R-squared: 0.9949
# 51의 평균 제곱 오차: 1.6348
# 51의 평균 절대 오차: 0.7699
# 51의 R-squared: 0.9970
# 52의 평균 제곱 오차: 2.0014
# 52의 평균 절대 오차: 1.0183
# 52의 R-squared: 0.9963
# 53의 평균 제곱 오차: 1.4785
# 53의 평균 절대 오차: 0.9518
# 53의 R-squared: 0.9972
# 56의 평균 제곱 오차: 0.2369
# 56의 평균 절대 오차: 0.4422
# 56의 R-squared: 0.9996
# 57의 평균 제곱 오차: 0.3980
# 57의 평균 절대 오차: 0.5797
# 57의 R-squared: 0.9993
# 58의 평균 제곱 오차: 0.1545
# 58의 평균 절대 오차: 0.3290
# 58의 R-squared: 0.9997
# 59의 평균 제곱 오차: 0.6528
# 59의 평균 절대 오차: 0.7041
# 59의 R-squared: 0.9988
# 60의 평균 제곱 오차: 0.4973
# 60의 평균 절대 오차: 0.5627
# 60의 R-squared: 0.9991
# 61의 평균 제곱 오차: 0.4288
# 61의 평균 절대 오차: 0.5122
# 61의 R-squared: 0.9992
# 62의 평균 제곱 오차: 0.1369
# 62의 평균 절대 오차: 0.3400
# 62의 R-squared: 0.9997
# 63의 평균 제곱 오차: 0.3228
# 63의 평균 절대 오차: 0.5207
# 63의 R-squared: 0.9994
# 64의 평균 제곱 오차: 0.2670
# 64의 평균 절대 오차: 0.4566
# 64의 R-squared: 0.9995
# 65의 평균 제곱 오차: 0.1657
# 65의 평균 절대 오차: 0.3642
# 65의 R-squared: 0.9997
# 66의 평균 제곱 오차: 0.3444
# 66의 평균 절대 오차: 0.5572
# 66의 R-squared: 0.9994
# 67의 평균 제곱 오차: 0.1261
# 67의 평균 절대 오차: 0.2611
# 67의 R-squared: 0.9998
# 68의 평균 제곱 오차: 0.2251
# 68의 평균 절대 오차: 0.4295
# 68의 R-squared: 0.9996
# 69의 평균 제곱 오차: 0.2310
# 69의 평균 절대 오차: 0.3713
# 69의 R-squared: 0.9996
# 70의 평균 제곱 오차: 0.3285
# 70의 평균 절대 오차: 0.4521
# 70의 R-squared: 0.9994
# 71의 평균 제곱 오차: 0.3329
# 71의 평균 절대 오차: 0.4683
# 71의 R-squared: 0.9994
# 72의 평균 제곱 오차: 0.2449
# 72의 평균 절대 오차: 0.4695
# 72의 R-squared: 0.9995
# 73의 평균 제곱 오차: 0.2502
# 73의 평균 절대 오차: 0.4039
# 73의 R-squared: 0.9995
# 74의 평균 제곱 오차: 0.3478
# 74의 평균 절대 오차: 0.5440
# 74의 R-squared: 0.9994
# 75의 평균 제곱 오차: 0.9860
# 75의 평균 절대 오차: 0.7382
# 75의 R-squared: 0.9982
# 76의 평균 제곱 오차: 0.5487
# 76의 평균 절대 오차: 0.6381
# 76의 R-squared: 0.9990
# 77의 평균 제곱 오차: 0.1444
# 77의 평균 절대 오차: 0.3027
# 77의 R-squared: 0.9997
# 78의 평균 제곱 오차: 1.0203
# 78의 평균 절대 오차: 0.6919
# 78의 R-squared: 0.9981
# 79의 평균 제곱 오차: 1.1166
# 79의 평균 절대 오차: 0.8078
# 79의 R-squared: 0.9979
# 80의 평균 제곱 오차: 0.9092
# 80의 평균 절대 오차: 0.7612
# 80의 R-squared: 0.9983
# 81의 평균 제곱 오차: 0.9016
# 81의 평균 절대 오차: 0.7095
# 81의 R-squared: 0.9983
# 82의 평균 제곱 오차: 1.0266
# 82의 평균 절대 오차: 0.8205
# 82의 R-squared: 0.9981
# 83의 평균 제곱 오차: 1.4722
# 83의 평균 절대 오차: 0.8761
# 83의 R-squared: 0.9973
# 84의 평균 제곱 오차: 3.3838
# 84의 평균 절대 오차: 1.1332
# 84의 R-squared: 0.9937
# 85의 평균 제곱 오차: 2.6830
# 85의 평균 절대 오차: 1.2027
# 85의 R-squared: 0.9950
# 86의 평균 제곱 오차: 2.9181
# 86의 평균 절대 오차: 1.1722
# 86의 R-squared: 0.9946
# 87의 평균 제곱 오차: 2.2227
# 87의 평균 절대 오차: 1.1520
# 87의 R-squared: 0.9959
# 88의 평균 제곱 오차: 2.7490
# 88의 평균 절대 오차: 1.1156
# 88의 R-squared: 0.9949
# 89의 평균 제곱 오차: 2.8269
# 89의 평균 절대 오차: 1.1875
# 89의 R-squared: 0.9947
# 90의 평균 제곱 오차: 2.8800
# 90의 평균 절대 오차: 1.2669
# 90의 R-squared: 0.9946
# 91의 평균 제곱 오차: 3.8512
# 91의 평균 절대 오차: 1.3033
# 91의 R-squared: 0.9928
# 93의 평균 제곱 오차: 3.3843
# 93의 평균 절대 오차: 1.0482
# 93의 R-squared: 0.9937
# 94의 평균 제곱 오차: 3.9194
# 94의 평균 절대 오차: 1.3719
# 94의 R-squared: 0.9927
# 95의 평균 제곱 오차: 2.0361
# 95의 평균 절대 오차: 1.1425
# 95의 R-squared: 0.9962
# 97의 평균 제곱 오차: 0.6598
# 97의 평균 절대 오차: 0.6213
# 97의 R-squared: 0.9988
# 98의 평균 제곱 오차: 1.4393
# 98의 평균 절대 오차: 0.6925
# 98의 R-squared: 0.9973
# 99의 평균 제곱 오차: 3.4564
# 99의 평균 절대 오차: 1.0796
# 99의 R-squared: 0.9936
# 100의 평균 제곱 오차: 1.9305
# 100의 평균 절대 오차: 0.8818
# 100의 R-squared: 0.9964
# 101의 평균 제곱 오차: 3.7299
# 101의 평균 절대 오차: 1.3055
# 101의 R-squared: 0.9930
# 102의 평균 제곱 오차: 3.9841
# 102의 평균 절대 오차: 1.4204
# 102의 R-squared: 0.9926
# 103의 평균 제곱 오차: 2.8161
# 103의 평균 절대 오차: 1.2005
# 103의 R-squared: 0.9947
# 104의 평균 제곱 오차: 2.7455
# 104의 평균 절대 오차: 1.0859
# 104의 R-squared: 0.9949
# 105의 평균 제곱 오차: 2.8000
# 105의 평균 절대 오차: 1.1629
# 105의 R-squared: 0.9948
# 106의 평균 제곱 오차: 2.0112
# 106의 평균 절대 오차: 0.9264
# 106의 R-squared: 0.9962
# 107의 평균 제곱 오차: 1.6425
# 107의 평균 절대 오차: 0.9485
# 107의 R-squared: 0.9969
# 108의 평균 제곱 오차: 1.9275
# 108의 평균 절대 오차: 0.9137
# 108의 R-squared: 0.9964
# 109의 평균 제곱 오차: 2.6945
# 109의 평균 절대 오차: 1.1004
# 109의 R-squared: 0.9950
# 110의 평균 제곱 오차: 2.9622
# 110의 평균 절대 오차: 1.2433
# 110의 R-squared: 0.9945
# 111의 평균 제곱 오차: 1.2142
# 111의 평균 절대 오차: 0.6923
# 111의 R-squared: 0.9977
# 112의 평균 제곱 오차: 2.0847
# 112의 평균 절대 오차: 1.0702
# 112의 R-squared: 0.9961
# 113의 평균 제곱 오차: 3.5246
# 113의 평균 절대 오차: 1.1149
# 113의 R-squared: 0.9934
# 114의 평균 제곱 오차: 2.7828
# 114의 평균 절대 오차: 1.1237
# 114의 R-squared: 0.9948
# 115의 평균 제곱 오차: 0.6583
# 115의 평균 절대 오차: 0.6013
# 115의 R-squared: 0.9988
# 116의 평균 제곱 오차: 1.3527
# 116의 평균 절대 오차: 0.8052
# 116의 R-squared: 0.9975
# 117의 평균 제곱 오차: 2.7726
# 117의 평균 절대 오차: 1.0901
# 117의 R-squared: 0.9948
# 118의 평균 제곱 오차: 0.3136
# 118의 평균 절대 오차: 0.4524
# 118의 R-squared: 0.9994
# 119의 평균 제곱 오차: 0.5530
# 119의 평균 절대 오차: 0.5452
# 119의 R-squared: 0.9990
# 120의 평균 제곱 오차: 0.8283
# 120의 평균 절대 오차: 0.7162
# 120의 R-squared: 0.9985
# 121의 평균 제곱 오차: 3.6219
# 121의 평균 절대 오차: 1.2703
# 121의 R-squared: 0.9932
# 122의 평균 제곱 오차: 1.8046
# 122의 평균 절대 오차: 0.9105
# 122의 R-squared: 0.9966
# 123의 평균 제곱 오차: 2.9873
# 123의 평균 절대 오차: 1.2483
# 123의 R-squared: 0.9944
# 124의 평균 제곱 오차: 1.1978
# 124의 평균 절대 오차: 0.7348
# 124의 R-squared: 0.9978
# 125의 평균 제곱 오차: 0.5271
# 125의 평균 절대 오차: 0.5818
# 125의 R-squared: 0.9990
# 126의 평균 제곱 오차: 0.7861
# 126의 평균 절대 오차: 0.6701
# 126의 R-squared: 0.9985
# 127의 평균 제곱 오차: 0.5845
# 127의 평균 절대 오차: 0.6434
# 127의 R-squared: 0.9989
# 128의 평균 제곱 오차: 1.1401
# 128의 평균 절대 오차: 0.7364
# 128의 R-squared: 0.9979
# 129의 평균 제곱 오차: 0.5950
# 129의 평균 절대 오차: 0.6443
# 129의 R-squared: 0.9989
# 130의 평균 제곱 오차: 0.7353
# 130의 평균 절대 오차: 0.6584
# 130의 R-squared: 0.9986
# 131의 평균 제곱 오차: 0.9205
# 131의 평균 절대 오차: 0.7996
# 131의 R-squared: 0.9983
# 132의 평균 제곱 오차: 1.1900
# 132의 평균 절대 오차: 0.7831
# 132의 R-squared: 0.9978
# 133의 평균 제곱 오차: 2.5527
# 133의 평균 절대 오차: 0.9759
# 133의 R-squared: 0.9952
# 134의 평균 제곱 오차: 2.6655
# 134의 평균 절대 오차: 1.0650
# 134의 R-squared: 0.9950
# 135의 평균 제곱 오차: 2.9693
# 135의 평균 절대 오차: 1.1748
# 135의 R-squared: 0.9945
# 136의 평균 제곱 오차: 1.8782
# 136의 평균 절대 오차: 0.9781
# 136의 R-squared: 0.9965
# 137의 평균 제곱 오차: 3.5169
# 137의 평균 절대 오차: 1.1211
# 137의 R-squared: 0.9934
# 138의 평균 제곱 오차: 2.9461
# 138의 평균 절대 오차: 1.1963
# 138의 R-squared: 0.9945
# 139의 평균 제곱 오차: 1.9958
# 139의 평균 절대 오차: 0.9347
# 139의 R-squared: 0.9963
# 140의 평균 제곱 오차: 1.9882
# 140의 평균 절대 오차: 1.0163
# 140의 R-squared: 0.9963
# 141의 평균 제곱 오차: 1.9024
# 141의 평균 절대 오차: 0.8746
# 141의 R-squared: 0.9965
# 142의 평균 제곱 오차: 3.6532
# 142의 평균 절대 오차: 1.1864
# 142의 R-squared: 0.9932
# 143의 평균 제곱 오차: 4.0156
# 143의 평균 절대 오차: 1.2861
# 143의 R-squared: 0.9925
# 144의 평균 제곱 오차: 2.1697
# 144의 평균 절대 오차: 1.1010
# 144의 R-squared: 0.9960
# 145의 평균 제곱 오차: 3.6969
# 145의 평균 절대 오차: 1.1850
# 145의 R-squared: 0.9931
# 146의 평균 제곱 오차: 1.8522
# 146의 평균 절대 오차: 0.8771
# 146의 R-squared: 0.9965
# 147의 평균 제곱 오차: 2.1281
# 147의 평균 절대 오차: 1.0066
# 147의 R-squared: 0.9960
# 148의 평균 제곱 오차: 1.8907
# 148의 평균 절대 오차: 0.8694
# 148의 R-squared: 0.9965
# 149의 평균 제곱 오차: 4.1160
# 149의 평균 절대 오차: 1.3572
# 149의 R-squared: 0.9923
# 150의 평균 제곱 오차: 1.7550
# 150의 평균 절대 오차: 0.8772
# 150의 R-squared: 0.9967
# 151의 평균 제곱 오차: 1.9183
# 151의 평균 절대 오차: 0.8801
# 151의 R-squared: 0.9964
# 152의 평균 제곱 오차: 2.7276
# 152의 평균 절대 오차: 1.1006
# 152의 R-squared: 0.9949
# 153의 평균 제곱 오차: 4.0233
# 153의 평균 절대 오차: 1.3911
# 153의 R-squared: 0.9925
# 154의 평균 제곱 오차: 3.6165
# 154의 평균 절대 오차: 1.1378
# 154의 R-squared: 0.9933
# 155의 평균 제곱 오차: 2.9439
# 155의 평균 절대 오차: 1.1904
# 155의 R-squared: 0.9945
# 156의 평균 제곱 오차: 2.6251
# 156의 평균 절대 오차: 0.9849
# 156의 R-squared: 0.9951
# 157의 평균 제곱 오차: 4.2351
# 157의 평균 절대 오차: 1.3895
# 157의 R-squared: 0.9921
# 158의 평균 제곱 오차: 2.6196
# 158의 평균 절대 오차: 1.1665
# 158의 R-squared: 0.9951
# 159의 평균 제곱 오차: 2.6053
# 159의 평균 절대 오차: 1.0675
# 159의 R-squared: 0.9951
# 160의 평균 제곱 오차: 2.5928
# 160의 평균 절대 오차: 1.1042
# 160의 R-squared: 0.9952
# 161의 평균 제곱 오차: 2.9822
# 161의 평균 절대 오차: 1.3017
# 161의 R-squared: 0.9944
# 162의 평균 제곱 오차: 1.7080
# 162의 평균 절대 오차: 0.9808
# 162의 R-squared: 0.9968
# 163의 평균 제곱 오차: 2.1154
# 163의 평균 절대 오차: 0.9671
# 163의 R-squared: 0.9961
# 164의 평균 제곱 오차: 3.4544
# 164의 평균 절대 오차: 1.2126
# 164의 R-squared: 0.9936
# 165의 평균 제곱 오차: 3.0099
# 165의 평균 절대 오차: 1.2446
# 165의 R-squared: 0.9944
# 166의 평균 제곱 오차: 3.4631
# 166의 평균 절대 오차: 1.1033
# 166의 R-squared: 0.9935
# 167의 평균 제곱 오차: 3.2775
# 167의 평균 절대 오차: 1.2701
# 167의 R-squared: 0.9939
# 168의 평균 제곱 오차: 2.7251
# 168의 평균 절대 오차: 1.0553
# 168의 R-squared: 0.9949
# 169의 평균 제곱 오차: 1.8591
# 169의 평균 절대 오차: 1.0087
# 169의 R-squared: 0.9965
# 170의 평균 제곱 오차: 2.9288
# 170의 평균 절대 오차: 1.1231
# 170의 R-squared: 0.9945
# 171의 평균 제곱 오차: 0.7652
# 171의 평균 절대 오차: 0.7241
# 171의 R-squared: 0.9986
# 172의 평균 제곱 오차: 0.6490
# 172의 평균 절대 오차: 0.6017
# 172의 R-squared: 0.9988
# 173의 평균 제곱 오차: 1.0085
# 173의 평균 절대 오차: 0.7069
# 173의 R-squared: 0.9981
# 174의 평균 제곱 오차: 0.7595
# 174의 평균 절대 오차: 0.5881
# 174의 R-squared: 0.9986
# 175의 평균 제곱 오차: 1.3083
# 175의 평균 절대 오차: 0.9085
# 175의 R-squared: 0.9976
# 176의 평균 제곱 오차: 1.1396
# 176의 평균 절대 오차: 0.7804
# 176의 R-squared: 0.9979
# 177의 평균 제곱 오차: 0.9401
# 177의 평균 절대 오차: 0.6812
# 177의 R-squared: 0.9982
# 178의 평균 제곱 오차: 1.2002
# 178의 평균 절대 오차: 0.8257
# 178의 R-squared: 0.9978
# 179의 평균 제곱 오차: 2.7490
# 179의 평균 절대 오차: 1.0306
# 179의 R-squared: 0.9949
# 180의 평균 제곱 오차: 1.0406
# 180의 평균 절대 오차: 0.7619
# 180의 R-squared: 0.9981
# 181의 평균 제곱 오차: 0.6532
# 181의 평균 절대 오차: 0.5360
# 181의 R-squared: 0.9988
# 182의 평균 제곱 오차: 0.7792
# 182의 평균 절대 오차: 0.7497
# 182의 R-squared: 0.9985
# 183의 평균 제곱 오차: 0.7284
# 183의 평균 절대 오차: 0.6770
# 183의 R-squared: 0.9986
# 184의 평균 제곱 오차: 2.8632
# 184의 평균 절대 오차: 1.0969
# 184의 R-squared: 0.9947
# 185의 평균 제곱 오차: 3.6015
# 185의 평균 절대 오차: 1.2037
# 185의 R-squared: 0.9933
# 186의 평균 제곱 오차: 1.4935
# 186의 평균 절대 오차: 0.8003
# 186의 R-squared: 0.9972
# 187의 평균 제곱 오차: 0.6125
# 187의 평균 절대 오차: 0.6782
# 187의 R-squared: 0.9989
# 188의 평균 제곱 오차: 1.1148
# 188의 평균 절대 오차: 0.7949
# 188의 R-squared: 0.9979
# 189의 평균 제곱 오차: 1.8092
# 189의 평균 절대 오차: 0.9485
# 189의 R-squared: 0.9966
# 190의 평균 제곱 오차: 1.6900
# 190의 평균 절대 오차: 1.0028
# 190의 R-squared: 0.9968
# 191의 평균 제곱 오차: 2.0905
# 191의 평균 절대 오차: 0.9667
# 191의 R-squared: 0.9961
# 192의 평균 제곱 오차: 2.1772
# 192의 평균 절대 오차: 1.0931
# 192의 R-squared: 0.9959
# 193의 평균 제곱 오차: 1.5548
# 193의 평균 절대 오차: 0.7959
# 193의 R-squared: 0.9971
# 194의 평균 제곱 오차: 2.4696
# 194의 평균 절대 오차: 1.0077
# 194의 R-squared: 0.9954
# 195의 평균 제곱 오차: 2.4667
# 195의 평균 절대 오차: 1.0154
# 195의 R-squared: 0.9954
# 196의 평균 제곱 오차: 1.8889
# 196의 평균 절대 오차: 0.9270
# 196의 R-squared: 0.9965
# 197의 평균 제곱 오차: 2.6491
# 197의 평균 절대 오차: 1.1110
# 197의 R-squared: 0.9951
# 198의 평균 제곱 오차: 3.6429
# 198의 평균 절대 오차: 1.1759
# 198의 R-squared: 0.9932
# 199의 평균 제곱 오차: 1.0398
# 199의 평균 절대 오차: 0.6674
# 199의 R-squared: 0.9981
# 200의 평균 제곱 오차: 2.8465
# 200의 평균 절대 오차: 1.1623
# 200의 R-squared: 0.9947
# 201의 평균 제곱 오차: 0.8567
# 201의 평균 절대 오차: 0.6641
# 201의 R-squared: 0.9984
# 202의 평균 제곱 오차: 2.8292
# 202의 평균 절대 오차: 1.0707
# 202의 R-squared: 0.9947
# 203의 평균 제곱 오차: 2.9166
# 203의 평균 절대 오차: 1.1001
# 203의 R-squared: 0.9946
# 204의 평균 제곱 오차: 2.9895
# 204의 평균 절대 오차: 1.2407
# 204의 R-squared: 0.9944
# 205의 평균 제곱 오차: 1.1395
# 205의 평균 절대 오차: 0.7639
# 205의 R-squared: 0.9979
# 206의 평균 제곱 오차: 2.5745
# 206의 평균 절대 오차: 1.0402
# 206의 R-squared: 0.9952
# 207의 평균 제곱 오차: 4.1937
# 207의 평균 절대 오차: 1.5335
# 207의 R-squared: 0.9922
# 208의 평균 제곱 오차: 4.1293
# 208의 평균 절대 오차: 1.3891
# 208의 R-squared: 0.9923
# 209의 평균 제곱 오차: 2.6517
# 209의 평균 절대 오차: 0.9809
# 209의 R-squared: 0.9951
# 210의 평균 제곱 오차: 3.4598
# 210의 평균 절대 오차: 1.1392
# 210의 R-squared: 0.9935
# 211의 평균 제곱 오차: 2.1689
# 211의 평균 절대 오차: 1.1397
# 211의 R-squared: 0.9960
# 212의 평균 제곱 오차: 3.8152
# 212의 평균 절대 오차: 1.3820
# 212의 R-squared: 0.9929
# 213의 평균 제곱 오차: 2.1764
# 213의 평균 절대 오차: 0.9647
# 213의 R-squared: 0.9959
# 214의 평균 제곱 오차: 2.7263
# 214의 평균 절대 오차: 1.1186
# 214의 R-squared: 0.9949
# 215의 평균 제곱 오차: 1.0962
# 215의 평균 절대 오차: 0.7893
# 215의 R-squared: 0.9980
# 216의 평균 제곱 오차: 1.6347
# 216의 평균 절대 오차: 0.7971
# 216의 R-squared: 0.9970
# 217의 평균 제곱 오차: 2.0148
# 217의 평균 절대 오차: 1.0420
# 217의 R-squared: 0.9962
# 218의 평균 제곱 오차: 2.7985
# 218의 평균 절대 오차: 1.1836
# 218의 R-squared: 0.9948
# 219의 평균 제곱 오차: 1.7931
# 219의 평균 절대 오차: 0.9410
# 219의 R-squared: 0.9967
# 220의 평균 제곱 오차: 2.9247
# 220의 평균 절대 오차: 1.0872
# 220의 R-squared: 0.9945
# 221의 평균 제곱 오차: 2.8648
# 221의 평균 절대 오차: 1.0637
# 221의 R-squared: 0.9947
# 222의 평균 제곱 오차: 1.0988
# 222의 평균 절대 오차: 0.7997
# 222의 R-squared: 0.9980
# 223의 평균 제곱 오차: 2.7639
# 223의 평균 절대 오차: 1.0852
# 223의 R-squared: 0.9948
# 224의 평균 제곱 오차: 0.3946
# 224의 평균 절대 오차: 0.4487
# 224의 R-squared: 0.9993
# 225의 평균 제곱 오차: 1.3364
# 225의 평균 절대 오차: 0.8091
# 225의 R-squared: 0.9975
# 226의 평균 제곱 오차: 0.6522
# 226의 평균 절대 오차: 0.6565
# 226의 R-squared: 0.9988
# 227의 평균 제곱 오차: 1.2140
# 227의 평균 절대 오차: 0.8059
# 227의 R-squared: 0.9977
# 228의 평균 제곱 오차: 0.5990
# 228의 평균 절대 오차: 0.5379
# 228의 R-squared: 0.9989
# 229의 평균 제곱 오차: 1.1720
# 229의 평균 절대 오차: 0.7162
# 229의 R-squared: 0.9978
# 230의 평균 제곱 오차: 1.0434
# 230의 평균 절대 오차: 0.7682
# 230의 R-squared: 0.9981
# 231의 평균 제곱 오차: 1.9559
# 231의 평균 절대 오차: 0.9565
# 231의 R-squared: 0.9964
# 232의 평균 제곱 오차: 0.7901
# 232의 평균 절대 오차: 0.6740
# 232의 R-squared: 0.9985
# 233의 평균 제곱 오차: 0.7591
# 233의 평균 절대 오차: 0.6654
# 233의 R-squared: 0.9986
# 234의 평균 제곱 오차: 0.4894
# 234의 평균 절대 오차: 0.5607
# 234의 R-squared: 0.9991
# 235의 평균 제곱 오차: 0.3255
# 235의 평균 절대 오차: 0.4653
# 235의 R-squared: 0.9994
# 236의 평균 제곱 오차: 0.2045
# 236의 평균 절대 오차: 0.3962
# 236의 R-squared: 0.9996
# 237의 평균 제곱 오차: 0.4157
# 237의 평균 절대 오차: 0.5506
# 237의 R-squared: 0.9992
# 238의 평균 제곱 오차: 0.5484
# 238의 평균 절대 오차: 0.6435
# 238의 R-squared: 0.9990
# 239의 평균 제곱 오차: 0.2734
# 239의 평균 절대 오차: 0.4096
# 239의 R-squared: 0.9995
# 240의 평균 제곱 오차: 0.6620
# 240의 평균 절대 오차: 0.7177
# 240의 R-squared: 0.9988
# 241의 평균 제곱 오차: 0.0426
# 241의 평균 절대 오차: 0.1744
# 241의 R-squared: 0.9999
# 242의 평균 제곱 오차: 0.1678
# 242의 평균 절대 오차: 0.3497
# 242의 R-squared: 0.9997
# 243의 평균 제곱 오차: 0.8033
# 243의 평균 절대 오차: 0.6374
# 243의 R-squared: 0.9985
# 244의 평균 제곱 오차: 0.1445
# 244의 평균 절대 오차: 0.3093
# 244의 R-squared: 0.9997
# 245의 평균 제곱 오차: 0.9969
# 245의 평균 절대 오차: 0.8491
# 245의 R-squared: 0.9981
# 246의 평균 제곱 오차: 0.5516
# 246의 평균 절대 오차: 0.6109
# 246의 R-squared: 0.9990
# 247의 평균 제곱 오차: 0.5129
# 247의 평균 절대 오차: 0.6227
# 247의 R-squared: 0.9990
# 248의 평균 제곱 오차: 1.1063
# 248의 평균 절대 오차: 0.6983
# 248의 R-squared: 0.9979
# 249의 평균 제곱 오차: 1.6124
# 249의 평균 절대 오차: 0.9503
# 249의 R-squared: 0.9970
# 250의 평균 제곱 오차: 1.0674
# 250의 평균 절대 오차: 0.8071
# 250의 R-squared: 0.9980
# 251의 평균 제곱 오차: 0.6014
# 251의 평균 절대 오차: 0.5816
# 251의 R-squared: 0.9989
# 252의 평균 제곱 오차: 1.1124
# 252의 평균 절대 오차: 0.7649
# 252의 R-squared: 0.9979
# 253의 평균 제곱 오차: 3.6943
# 253의 평균 절대 오차: 1.2488
# 253의 R-squared: 0.9931
# 254의 평균 제곱 오차: 1.9116
# 254의 평균 절대 오차: 0.8946
# 254의 R-squared: 0.9964
# 255의 평균 제곱 오차: 2.1340
# 255의 평균 절대 오차: 1.1327
# 255의 R-squared: 0.9960
# 256의 평균 제곱 오차: 1.7665
# 256의 평균 절대 오차: 1.0441
# 256의 R-squared: 0.9967
# 257의 평균 제곱 오차: 0.9540
# 257의 평균 절대 오차: 0.7653
# 257의 R-squared: 0.9982
# 258의 평균 제곱 오차: 0.8139
# 258의 평균 절대 오차: 0.6589
# 258의 R-squared: 0.9985
# 259의 평균 제곱 오차: 1.6987
# 259의 평균 절대 오차: 0.8730
# 259의 R-squared: 0.9968
# 260의 평균 제곱 오차: 1.9325
# 260의 평균 절대 오차: 1.0257
# 260의 R-squared: 0.9964
# 261의 평균 제곱 오차: 1.6535
# 261의 평균 절대 오차: 0.9980
# 261의 R-squared: 0.9969
# 262의 평균 제곱 오차: 1.6355
# 262의 평균 절대 오차: 0.8788
# 262의 R-squared: 0.9969
# 263의 평균 제곱 오차: 1.2197
# 263의 평균 절대 오차: 0.6724
# 263의 R-squared: 0.9977
# 264의 평균 제곱 오차: 2.5506
# 264의 평균 절대 오차: 1.1197
# 264의 R-squared: 0.9952
# 265의 평균 제곱 오차: 1.1279
# 265의 평균 절대 오차: 0.8006
# 265의 R-squared: 0.9979
# 266의 평균 제곱 오차: 1.0982
# 266의 평균 절대 오차: 0.7430
# 266의 R-squared: 0.9980
# 267의 평균 제곱 오차: 2.5699
# 267의 평균 절대 오차: 1.1190
# 267의 R-squared: 0.9952
# 268의 평균 제곱 오차: 2.6835
# 268의 평균 절대 오차: 1.0762
# 268의 R-squared: 0.9950
# 269의 평균 제곱 오차: 2.7919
# 269의 평균 절대 오차: 1.1506
# 269의 R-squared: 0.9948
# 270의 평균 제곱 오차: 3.4607
# 270의 평균 절대 오차: 1.1707
# 270의 R-squared: 0.9935
# 271의 평균 제곱 오차: 1.3555
# 271의 평균 절대 오차: 0.9013
# 271의 R-squared: 0.9975
# 272의 평균 제곱 오차: 2.1080
# 272의 평균 절대 오차: 1.0276
# 272의 R-squared: 0.9961
# 273의 평균 제곱 오차: 1.7174
# 273의 평균 절대 오차: 0.9164
# 273의 R-squared: 0.9968
# 274의 평균 제곱 오차: 1.0081
# 274의 평균 절대 오차: 0.8928
# 274의 R-squared: 0.9981
# 275의 평균 제곱 오차: 2.6013
# 275의 평균 절대 오차: 1.1186
# 275의 R-squared: 0.9951
# 276의 평균 제곱 오차: 1.8634
# 276의 평균 절대 오차: 0.9171
# 276의 R-squared: 0.9965
# 277의 평균 제곱 오차: 0.8021
# 277의 평균 절대 오차: 0.7267
# 277의 R-squared: 0.9985
# 278의 평균 제곱 오차: 1.2478
# 278의 평균 절대 오차: 0.8995
# 278의 R-squared: 0.9977
# 279의 평균 제곱 오차: 1.6432
# 279의 평균 절대 오차: 0.8502
# 279의 R-squared: 0.9969
# 280의 평균 제곱 오차: 2.7648
# 280의 평균 절대 오차: 1.1144
# 280의 R-squared: 0.9948
# 281의 평균 제곱 오차: 2.7665
# 281의 평균 절대 오차: 1.0920
# 281의 R-squared: 0.9948
# 282의 평균 제곱 오차: 1.9839
# 282의 평균 절대 오차: 1.1048
# 282의 R-squared: 0.9963
# 283의 평균 제곱 오차: 3.7967
# 283의 평균 절대 오차: 1.2654
# 283의 R-squared: 0.9929
# 284의 평균 제곱 오차: 2.9492
# 284의 평균 절대 오차: 1.2765
# 284의 R-squared: 0.9945
# 285의 평균 제곱 오차: 1.8294
# 285의 평균 절대 오차: 0.9768
# 285의 R-squared: 0.9966
# 286의 평균 제곱 오차: 3.1428
# 286의 평균 절대 오차: 1.3516
# 286의 R-squared: 0.9941
# 287의 평균 제곱 오차: 2.8582
# 287의 평균 절대 오차: 1.1419
# 287의 R-squared: 0.9947
# 288의 평균 제곱 오차: 4.1983
# 288의 평균 절대 오차: 1.4268
# 288의 R-squared: 0.9922
# 289의 평균 제곱 오차: 4.3908
# 289의 평균 절대 오차: 1.5812
# 289의 R-squared: 0.9918
# 290의 평균 제곱 오차: 3.8742
# 290의 평균 절대 오차: 1.3417
# 290의 R-squared: 0.9928
# 291의 평균 제곱 오차: 4.3461
# 291의 평균 절대 오차: 1.5195
# 291의 R-squared: 0.9919
# 292의 평균 제곱 오차: 2.1721
# 292의 평균 절대 오차: 1.0814
# 292의 R-squared: 0.9959
# 293의 평균 제곱 오차: 3.6285
# 293의 평균 절대 오차: 1.4420
# 293의 R-squared: 0.9932
# 294의 평균 제곱 오차: 1.2818
# 294의 평균 절대 오차: 0.8365
# 294의 R-squared: 0.9976
# 295의 평균 제곱 오차: 1.1429
# 295의 평균 절대 오차: 0.7629
# 295의 R-squared: 0.9979
# 296의 평균 제곱 오차: 1.6053
# 296의 평균 절대 오차: 0.8848
# 296의 R-squared: 0.9970
# 297의 평균 제곱 오차: 1.9820
# 297의 평균 절대 오차: 0.9856
# 297의 R-squared: 0.9963
# 298의 평균 제곱 오차: 0.9577
# 298의 평균 절대 오차: 0.7800
# 298의 R-squared: 0.9982
# 299의 평균 제곱 오차: 0.3801
# 299의 평균 절대 오차: 0.4506
# 299의 R-squared: 0.9993
# 300의 평균 제곱 오차: 1.2612
# 300의 평균 절대 오차: 0.8251
# 300의 R-squared: 0.9976
# 301의 평균 제곱 오차: 1.0983
# 301의 평균 절대 오차: 0.7408
# 301의 R-squared: 0.9980
# 302의 평균 제곱 오차: 3.2416
# 302의 평균 절대 오차: 1.3217
# 302의 R-squared: 0.9940
# 303의 평균 제곱 오차: 0.7464
# 303의 평균 절대 오차: 0.6708
# 303의 R-squared: 0.9986
# 304의 평균 제곱 오차: 1.3353
# 304의 평균 절대 오차: 0.8976
# 304의 R-squared: 0.9975
# 305의 평균 제곱 오차: 1.3677
# 305의 평균 절대 오차: 0.8904
# 305의 R-squared: 0.9974
# 306의 평균 제곱 오차: 0.5987
# 306의 평균 절대 오차: 0.6154
# 306의 R-squared: 0.9989
# 307의 평균 제곱 오차: 0.6941
# 307의 평균 절대 오차: 0.6979
# 307의 R-squared: 0.9987
# 308의 평균 제곱 오차: 0.8803
# 308의 평균 절대 오차: 0.5965
# 308의 R-squared: 0.9984
# 309의 평균 제곱 오차: 0.3538
# 309의 평균 절대 오차: 0.4204
# 309의 R-squared: 0.9993
# 310의 평균 제곱 오차: 0.7046
# 310의 평균 절대 오차: 0.6333
# 310의 R-squared: 0.9987
# 311의 평균 제곱 오차: 0.5974
# 311의 평균 절대 오차: 0.6227
# 311의 R-squared: 0.9989
# 312의 평균 제곱 오차: 2.8478
# 312의 평균 절대 오차: 1.1617
# 312의 R-squared: 0.9947
# 313의 평균 제곱 오차: 1.1531
# 313의 평균 절대 오차: 0.7627
# 313의 R-squared: 0.9978
# 314의 평균 제곱 오차: 0.6778
# 314의 평균 절대 오차: 0.6392
# 314의 R-squared: 0.9987
# 315의 평균 제곱 오차: 0.7812
# 315의 평균 절대 오차: 0.7768
# 315의 R-squared: 0.9985
# 316의 평균 제곱 오차: 0.5839
# 316의 평균 절대 오차: 0.6414
# 316의 R-squared: 0.9989
# 317의 평균 제곱 오차: 0.4704
# 317의 평균 절대 오차: 0.5832
# 317의 R-squared: 0.9991
# 318의 평균 제곱 오차: 1.1584
# 318의 평균 절대 오차: 0.8120
# 318의 R-squared: 0.9978
# 319의 평균 제곱 오차: 0.7236
# 319의 평균 절대 오차: 0.6923
# 319의 R-squared: 0.9987
# 320의 평균 제곱 오차: 0.8111
# 320의 평균 절대 오차: 0.6367
# 320의 R-squared: 0.9985
# 321의 평균 제곱 오차: 0.4226
# 321의 평균 절대 오차: 0.5243
# 321의 R-squared: 0.9992
# 322의 평균 제곱 오차: 0.4971
# 322의 평균 절대 오차: 0.5360
# 322의 R-squared: 0.9991
# 323의 평균 제곱 오차: 0.2067
# 323의 평균 절대 오차: 0.3613
# 323의 R-squared: 0.9996
# 324의 평균 제곱 오차: 0.8073
# 324의 평균 절대 오차: 0.7468
# 324의 R-squared: 0.9985
# 325의 평균 제곱 오차: 0.3175
# 325의 평균 절대 오차: 0.4947
# 325의 R-squared: 0.9994
# 326의 평균 제곱 오차: 0.8032
# 326의 평균 절대 오차: 0.7691
# 326의 R-squared: 0.9985
# 327의 평균 제곱 오차: 2.7794
# 327의 평균 절대 오차: 1.1507
# 327의 R-squared: 0.9948
# 328의 평균 제곱 오차: 1.3644
# 328의 평균 절대 오차: 0.8908
# 328의 R-squared: 0.9975
# 329의 평균 제곱 오차: 2.6282
# 329의 평균 절대 오차: 1.0897
# 329의 R-squared: 0.9951
# 331의 평균 제곱 오차: 3.7383
# 331의 평균 절대 오차: 1.2762
# 331의 R-squared: 0.9930
# 332의 평균 제곱 오차: 1.9776
# 332의 평균 절대 오차: 0.9871
# 332의 R-squared: 0.9963
# 333의 평균 제곱 오차: 2.2435
# 333의 평균 절대 오차: 0.9849
# 333의 R-squared: 0.9958
# 334의 평균 제곱 오차: 1.1056
# 334의 평균 절대 오차: 0.7491
# 334의 R-squared: 0.9979
# 335의 평균 제곱 오차: 3.2179
# 335의 평균 절대 오차: 1.2143
# 335의 R-squared: 0.9940
# 336의 평균 제곱 오차: 3.1560
# 336의 평균 절대 오차: 1.3299
# 336의 R-squared: 0.9941
# 337의 평균 제곱 오차: 0.9699
# 337의 평균 절대 오차: 0.7671
# 337의 R-squared: 0.9982
# 338의 평균 제곱 오차: 1.7716
# 338의 평균 절대 오차: 1.0302
# 338의 R-squared: 0.9967
# 339의 평균 제곱 오차: 1.8803
# 339의 평균 절대 오차: 0.9475
# 339의 R-squared: 0.9965
# 340의 평균 제곱 오차: 2.0799
# 340의 평균 절대 오차: 1.1359
# 340의 R-squared: 0.9961
# 341의 평균 제곱 오차: 1.9911
# 341의 평균 절대 오차: 1.0184
# 341의 R-squared: 0.9963
# 342의 평균 제곱 오차: 3.6945
# 342의 평균 절대 오차: 1.2856
# 342의 R-squared: 0.9931
# 343의 평균 제곱 오차: 1.6338
# 343의 평균 절대 오차: 1.1137
# 343의 R-squared: 0.9970
# 344의 평균 제곱 오차: 2.1205
# 344의 평균 절대 오차: 1.1017
# 344의 R-squared: 0.9960
# 345의 평균 제곱 오차: 4.7348
# 345의 평균 절대 오차: 1.2996
# 345의 R-squared: 0.9912
# 346의 평균 제곱 오차: 1.1123
# 346의 평균 절대 오차: 0.7517
# 346의 R-squared: 0.9979
# 347의 평균 제곱 오차: 1.0739
# 347의 평균 절대 오차: 0.7722
# 347의 R-squared: 0.9980
# 348의 평균 제곱 오차: 1.7179
# 348의 평균 절대 오차: 0.9296
# 348의 R-squared: 0.9968
# 349의 평균 제곱 오차: 2.7186
# 349의 평균 절대 오차: 1.0631
# 349의 R-squared: 0.9949
# 350의 평균 제곱 오차: 2.4056
# 350의 평균 절대 오차: 1.0877
# 350의 R-squared: 0.9955
# 351의 평균 제곱 오차: 3.0866
# 351의 평균 절대 오차: 1.2556
# 351의 R-squared: 0.9942
# 352의 평균 제곱 오차: 3.8652
# 352의 평균 절대 오차: 1.1904
# 352의 R-squared: 0.9928
# 353의 평균 제곱 오차: 2.6526
# 353의 평균 절대 오차: 0.9981
# 353의 R-squared: 0.9951
# 354의 평균 제곱 오차: 2.1087
# 354의 평균 절대 오차: 1.0092
# 354의 R-squared: 0.9961
# 355의 평균 제곱 오차: 2.5621
# 355의 평균 절대 오차: 1.1068
# 355의 R-squared: 0.9952
# 356의 평균 제곱 오차: 1.7646
# 356의 평균 절대 오차: 0.9906
# 356의 R-squared: 0.9967
# 357의 평균 제곱 오차: 1.6895
# 357의 평균 절대 오차: 0.8686
# 357의 R-squared: 0.9968
# 358의 평균 제곱 오차: 3.4168
# 358의 평균 절대 오차: 1.1563
# 358의 R-squared: 0.9936
# 359의 평균 제곱 오차: 0.4925
# 359의 평균 절대 오차: 0.5932
# 359의 R-squared: 0.9991
# 360의 평균 제곱 오차: 0.7992
# 360의 평균 절대 오차: 0.6785
# 360의 R-squared: 0.9985
# 361의 평균 제곱 오차: 0.4200
# 361의 평균 절대 오차: 0.5122
# 361의 R-squared: 0.9992
# 362의 평균 제곱 오차: 0.4410
# 362의 평균 절대 오차: 0.5529
# 362의 R-squared: 0.9992
# 363의 평균 제곱 오차: 0.2437
# 363의 평균 절대 오차: 0.3754
# 363의 R-squared: 0.9995
# 364의 평균 제곱 오차: 1.0202
# 364의 평균 절대 오차: 0.7377
# 364의 R-squared: 0.9981
# 365의 평균 제곱 오차: 0.4420
# 365의 평균 절대 오차: 0.4208
# 365의 R-squared: 0.9992
# 366의 평균 제곱 오차: 0.5103
# 366의 평균 절대 오차: 0.5426
# 366의 R-squared: 0.9990
# 367의 평균 제곱 오차: 0.4809
# 367의 평균 절대 오차: 0.5737
# 367의 R-squared: 0.9991
# 368의 평균 제곱 오차: 0.6720
# 368의 평균 절대 오차: 0.6914
# 368의 R-squared: 0.9987
# 369의 평균 제곱 오차: 0.3028
# 369의 평균 절대 오차: 0.4763
# 369의 R-squared: 0.9994
# 370의 평균 제곱 오차: 0.4655
# 370의 평균 절대 오차: 0.6152
# 370의 R-squared: 0.9991
# 371의 평균 제곱 오차: 0.3149
# 371의 평균 절대 오차: 0.5171
# 371의 R-squared: 0.9994
# 372의 평균 제곱 오차: 0.6520
# 372의 평균 절대 오차: 0.5314
# 372의 R-squared: 0.9988
# 373의 평균 제곱 오차: 0.8157
# 373의 평균 절대 오차: 0.7341
# 373의 R-squared: 0.9985
# 374의 평균 제곱 오차: 0.6497
# 374의 평균 절대 오차: 0.6572
# 374의 R-squared: 0.9988
# 375의 평균 제곱 오차: 1.1272
# 375의 평균 절대 오차: 0.7803
# 375의 R-squared: 0.9979
# 376의 평균 제곱 오차: 0.8604
# 376의 평균 절대 오차: 0.7603
# 376의 R-squared: 0.9984
# 377의 평균 제곱 오차: 0.3284
# 377의 평균 절대 오차: 0.5129
# 377의 R-squared: 0.9994
# 378의 평균 제곱 오차: 0.4012
# 378의 평균 절대 오차: 0.5311
# 378의 R-squared: 0.9993
# 379의 평균 제곱 오차: 1.9641
# 379의 평균 절대 오차: 0.9461
# 379의 R-squared: 0.9963
# 380의 평균 제곱 오차: 0.9946
# 380의 평균 절대 오차: 0.7516
# 380의 R-squared: 0.9981
# 381의 평균 제곱 오차: 1.2024
# 381의 평균 절대 오차: 0.7771
# 381의 R-squared: 0.9978
# 382의 평균 제곱 오차: 1.6250
# 382의 평균 절대 오차: 0.9078
# 382의 R-squared: 0.9970
# 383의 평균 제곱 오차: 0.4205
# 383의 평균 절대 오차: 0.4143
# 383의 R-squared: 0.9992
# 384의 평균 제곱 오차: 0.6315
# 384의 평균 절대 오차: 0.6491
# 384의 R-squared: 0.9988
# 385의 평균 제곱 오차: 0.6082
# 385의 평균 절대 오차: 0.6173
# 385의 R-squared: 0.9989
# 386의 평균 제곱 오차: 1.2780
# 386의 평균 절대 오차: 0.8303
# 386의 R-squared: 0.9976
# 387의 평균 제곱 오차: 1.8703
# 387의 평균 절대 오차: 1.0518
# 387의 R-squared: 0.9965
# 388의 평균 제곱 오차: 0.5276
# 388의 평균 절대 오차: 0.5830
# 388의 R-squared: 0.9990
# 389의 평균 제곱 오차: 0.7736
# 389의 평균 절대 오차: 0.7296
# 389의 R-squared: 0.9986
# 390의 평균 제곱 오차: 0.5171
# 390의 평균 절대 오차: 0.5355
# 390의 R-squared: 0.9990
# 391의 평균 제곱 오차: 1.3122
# 391의 평균 절대 오차: 0.7700
# 391의 R-squared: 0.9976
# 392의 평균 제곱 오차: 1.1610
# 392의 평균 절대 오차: 0.8150
# 392의 R-squared: 0.9978
# 393의 평균 제곱 오차: 0.6234
# 393의 평균 절대 오차: 0.5832
# 393의 R-squared: 0.9988
# 394의 평균 제곱 오차: 1.1789
# 394의 평균 절대 오차: 0.8235
# 394의 R-squared: 0.9978
# 395의 평균 제곱 오차: 0.7337
# 395의 평균 절대 오차: 0.6346
# 395의 R-squared: 0.9986
# 396의 평균 제곱 오차: 0.4070
# 396의 평균 절대 오차: 0.5944
# 396의 R-squared: 0.9992
# 398의 평균 제곱 오차: 0.4900
# 398의 평균 절대 오차: 0.5673
# 398의 R-squared: 0.9991
# 401의 평균 제곱 오차: 1.2535
# 401의 평균 절대 오차: 0.9972
# 401의 R-squared: 0.9977
# 402의 평균 제곱 오차: 0.6196
# 402의 평균 절대 오차: 0.6770
# 402의 R-squared: 0.9988
# 403의 평균 제곱 오차: 0.4372
# 403의 평균 절대 오차: 0.5535
# 403의 R-squared: 0.9992
# 404의 평균 제곱 오차: 0.4370
# 404의 평균 절대 오차: 0.5709
# 404의 R-squared: 0.9992
# 405의 평균 제곱 오차: 0.3750
# 405의 평균 절대 오차: 0.4257
# 405의 R-squared: 0.9993
# 406의 평균 제곱 오차: 0.4000
# 406의 평균 절대 오차: 0.5900
# 406의 R-squared: 0.9993
# 407의 평균 제곱 오차: 0.2482
# 407의 평균 절대 오차: 0.4134
# 407의 R-squared: 0.9995
# 408의 평균 제곱 오차: 0.2318
# 408의 평균 절대 오차: 0.3739
# 408의 R-squared: 0.9996
# 409의 평균 제곱 오차: 0.6599
# 409의 평균 절대 오차: 0.6372
# 409의 R-squared: 0.9988
# 410의 평균 제곱 오차: 0.2561
# 410의 평균 절대 오차: 0.4158
# 410의 R-squared: 0.9995
# 411의 평균 제곱 오차: 0.4477
# 411의 평균 절대 오차: 0.5425
# 411의 R-squared: 0.9992
# 412의 평균 제곱 오차: 0.2584
# 412의 평균 절대 오차: 0.4154
# 412의 R-squared: 0.9995
# 413의 평균 제곱 오차: 0.1280
# 413의 평균 절대 오차: 0.3056
# 413의 R-squared: 0.9998
# 414의 평균 제곱 오차: 0.2690
# 414의 평균 절대 오차: 0.4109
# 414의 R-squared: 0.9995
# 416의 평균 제곱 오차: 0.2428
# 416의 평균 절대 오차: 0.3846
# 416의 R-squared: 0.9995
# 417의 평균 제곱 오차: 0.1517
# 417의 평균 절대 오차: 0.2839
# 417의 R-squared: 0.9997
# 418의 평균 제곱 오차: 0.5390
# 418의 평균 절대 오차: 0.6358
# 418의 R-squared: 0.9990
# 419의 평균 제곱 오차: 0.3776
# 419의 평균 절대 오차: 0.5017
# 419의 R-squared: 0.9993
# 420의 평균 제곱 오차: 0.4786
# 420의 평균 절대 오차: 0.5269
# 420의 R-squared: 0.9991
# 421의 평균 제곱 오차: 1.0340
# 421의 평균 절대 오차: 0.7343
# 421의 R-squared: 0.9981
# 422의 평균 제곱 오차: 0.3557
# 422의 평균 절대 오차: 0.5248
# 422의 R-squared: 0.9993
# 423의 평균 제곱 오차: 0.4043
# 423의 평균 절대 오차: 0.5610
# 423의 R-squared: 0.9992
# 424의 평균 제곱 오차: 0.3272
# 424의 평균 절대 오차: 0.4877
# 424의 R-squared: 0.9994
# 425의 평균 제곱 오차: 1.2400
# 425의 평균 절대 오차: 0.8478
# 425의 R-squared: 0.9977
# 426의 평균 제곱 오차: 3.0339
# 426의 평균 절대 오차: 1.2439
# 426의 R-squared: 0.9943
# 427의 평균 제곱 오차: 0.4245
# 427의 평균 절대 오차: 0.5085
# 427의 R-squared: 0.9992
# 428의 평균 제곱 오차: 1.1610
# 428의 평균 절대 오차: 0.8577
# 428의 R-squared: 0.9978
# 429의 평균 제곱 오차: 1.5189
# 429의 평균 절대 오차: 0.9144
# 429의 R-squared: 0.9972
# 430의 평균 제곱 오차: 0.5675
# 430의 평균 절대 오차: 0.5649
# 430의 R-squared: 0.9989
# 431의 평균 제곱 오차: 0.7971
# 431의 평균 절대 오차: 0.7161
# 431의 R-squared: 0.9985
# 432의 평균 제곱 오차: 2.9467
# 432의 평균 절대 오차: 1.0795
# 432의 R-squared: 0.9945
# 433의 평균 제곱 오차: 5.1744
# 433의 평균 절대 오차: 1.4440
# 433의 R-squared: 0.9903
# 434의 평균 제곱 오차: 3.0329
# 434의 평균 절대 오차: 1.2936
# 434의 R-squared: 0.9943
# 435의 평균 제곱 오차: 4.0844
# 435의 평균 절대 오차: 1.2838
# 435의 R-squared: 0.9924
# 436의 평균 제곱 오차: 2.7681
# 436의 평균 절대 오차: 1.1101
# 436의 R-squared: 0.9948
# 437의 평균 제곱 오차: 2.6637
# 437의 평균 절대 오차: 1.1363
# 437의 R-squared: 0.9950
# 438의 평균 제곱 오차: 2.0431
# 438의 평균 절대 오차: 0.9525
# 438의 R-squared: 0.9962
# 439의 평균 제곱 오차: 3.8071
# 439의 평균 절대 오차: 1.2297
# 439의 R-squared: 0.9929
# 440의 평균 제곱 오차: 0.6726
# 440의 평균 절대 오차: 0.6737
# 440의 R-squared: 0.9987
# 441의 평균 제곱 오차: 0.8072
# 441의 평균 절대 오차: 0.7108
# 441의 R-squared: 0.9985
# 442의 평균 제곱 오차: 1.8817
# 442의 평균 절대 오차: 0.9441
# 442의 R-squared: 0.9965
# 443의 평균 제곱 오차: 2.1126
# 443의 평균 절대 오차: 1.0706
# 443의 R-squared: 0.9961
# 444의 평균 제곱 오차: 1.8436
# 444의 평균 절대 오차: 1.0333
# 444의 R-squared: 0.9966
# 445의 평균 제곱 오차: 3.5235
# 445의 평균 절대 오차: 1.0740
# 445의 R-squared: 0.9934
# 446의 평균 제곱 오차: 1.9867
# 446의 평균 절대 오차: 1.0518
# 446의 R-squared: 0.9963
# 447의 평균 제곱 오차: 2.5796
# 447의 평균 절대 오차: 1.0758
# 447의 R-squared: 0.9952
# 448의 평균 제곱 오차: 2.0274
# 448의 평균 절대 오차: 1.0174
# 448의 R-squared: 0.9962
# 449의 평균 제곱 오차: 1.1792
# 449의 평균 절대 오차: 0.8120
# 449의 R-squared: 0.9978
# 450의 평균 제곱 오차: 1.2398
# 450의 평균 절대 오차: 0.8576
# 450의 R-squared: 0.9977
# 451의 평균 제곱 오차: 1.4776
# 451의 평균 절대 오차: 0.8937
# 451의 R-squared: 0.9972
# 452의 평균 제곱 오차: 1.2155
# 452의 평균 절대 오차: 0.8065
# 452의 R-squared: 0.9977
# 453의 평균 제곱 오차: 0.7727
# 453의 평균 절대 오차: 0.7353
# 453의 R-squared: 0.9986
# 454의 평균 제곱 오차: 1.3312
# 454의 평균 절대 오차: 0.8013
# 454의 R-squared: 0.9975
# 455의 평균 제곱 오차: 0.9250
# 455의 평균 절대 오차: 0.6665
# 455의 R-squared: 0.9983
# 456의 평균 제곱 오차: 0.5790
# 456의 평균 절대 오차: 0.6404
# 456의 R-squared: 0.9989
# 457의 평균 제곱 오차: 0.5331
# 457의 평균 절대 오차: 0.5837
# 457의 R-squared: 0.9990
# 458의 평균 제곱 오차: 0.5333
# 458의 평균 절대 오차: 0.6644
# 458의 R-squared: 0.9990
# 459의 평균 제곱 오차: 0.3932
# 459의 평균 절대 오차: 0.5444
# 459의 R-squared: 0.9993
# 460의 평균 제곱 오차: 0.7100
# 460의 평균 절대 오차: 0.6907
# 460의 R-squared: 0.9987
# 461의 평균 제곱 오차: 0.7354
# 461의 평균 절대 오차: 0.6302
# 461의 R-squared: 0.9986
# 462의 평균 제곱 오차: 0.7633
# 462의 평균 절대 오차: 0.5416
# 462의 R-squared: 0.9986
# 463의 평균 제곱 오차: 2.2688
# 463의 평균 절대 오차: 0.9904
# 463의 R-squared: 0.9958
# 464의 평균 제곱 오차: 0.6463
# 464의 평균 절대 오차: 0.6490
# 464의 R-squared: 0.9988
# 465의 평균 제곱 오차: 1.0159
# 465의 평균 절대 오차: 0.7712
# 465의 R-squared: 0.9981
# 466의 평균 제곱 오차: 0.3945
# 466의 평균 절대 오차: 0.4396
# 466의 R-squared: 0.9993
# 467의 평균 제곱 오차: 0.2574
# 467의 평균 절대 오차: 0.4572
# 467의 R-squared: 0.9995
# 468의 평균 제곱 오차: 1.3259
# 468의 평균 절대 오차: 0.8572
# 468의 R-squared: 0.9975
# 469의 평균 제곱 오차: 2.1296
# 469의 평균 절대 오차: 1.0940
# 469의 R-squared: 0.9960
# 470의 평균 제곱 오차: 3.5425
# 470의 평균 절대 오차: 1.1004
# 470의 R-squared: 0.9934
# 471의 평균 제곱 오차: 0.5667
# 471의 평균 절대 오차: 0.6418
# 471의 R-squared: 0.9989
# 472의 평균 제곱 오차: 3.7271
# 472의 평균 절대 오차: 1.1846
# 472의 R-squared: 0.9930
# 473의 평균 제곱 오차: 2.3266
# 473의 평균 절대 오차: 1.0858
# 473의 R-squared: 0.9957
# 474의 평균 제곱 오차: 2.5229
# 474의 평균 절대 오차: 1.0078
# 474의 R-squared: 0.9953
# 475의 평균 제곱 오차: 2.7301
# 475의 평균 절대 오차: 1.1058
# 475의 R-squared: 0.9949
# 476의 평균 제곱 오차: 0.8556
# 476의 평균 절대 오차: 0.6799
# 476의 R-squared: 0.9984
# 477의 평균 제곱 오차: 0.4647
# 477의 평균 절대 오차: 0.4887
# 477의 R-squared: 0.9991
# 478의 평균 제곱 오차: 0.9913
# 478의 평균 절대 오차: 0.8757
# 478의 R-squared: 0.9982
# 479의 평균 제곱 오차: 2.8781
# 479의 평균 절대 오차: 1.0945
# 479의 R-squared: 0.9946
# 480의 평균 제곱 오차: 0.4733
# 480의 평균 절대 오차: 0.5673
# 480의 R-squared: 0.9991
# 481의 평균 제곱 오차: 0.3262
# 481의 평균 절대 오차: 0.4954
# 481의 R-squared: 0.9994
# 482의 평균 제곱 오차: 1.9868
# 482의 평균 절대 오차: 0.9277
# 482의 R-squared: 0.9963
# 483의 평균 제곱 오차: 0.5441
# 483의 평균 절대 오차: 0.6164
# 483의 R-squared: 0.9990
# 484의 평균 제곱 오차: 0.6611
# 484의 평균 절대 오차: 0.6495
# 484의 R-squared: 0.9988
# 485의 평균 제곱 오차: 1.1184
# 485의 평균 절대 오차: 0.8930
# 485의 R-squared: 0.9979
# 486의 평균 제곱 오차: 0.5762
# 486의 평균 절대 오차: 0.5781
# 486의 R-squared: 0.9989
# 487의 평균 제곱 오차: 0.6154
# 487의 평균 절대 오차: 0.6701
# 487의 R-squared: 0.9989
# 488의 평균 제곱 오차: 0.6739
# 488의 평균 절대 오차: 0.6966
# 488의 R-squared: 0.9987
# 489의 평균 제곱 오차: 0.9110
# 489의 평균 절대 오차: 0.7948
# 489의 R-squared: 0.9983
# 490의 평균 제곱 오차: 1.8094
# 490의 평균 절대 오차: 0.8570
# 490의 R-squared: 0.9966
# 491의 평균 제곱 오차: 1.3355
# 491의 평균 절대 오차: 0.9052
# 491의 R-squared: 0.9975
# 492의 평균 제곱 오차: 0.5668
# 492의 평균 절대 오차: 0.6342
# 492의 R-squared: 0.9989
# 493의 평균 제곱 오차: 0.7291
# 493의 평균 절대 오차: 0.6925
# 493의 R-squared: 0.9986
# 494의 평균 제곱 오차: 0.3380
# 494의 평균 절대 오차: 0.4875
# 494의 R-squared: 0.9994
# 495의 평균 제곱 오차: 1.2698
# 495의 평균 절대 오차: 0.8142
# 495의 R-squared: 0.9976
# 496의 평균 제곱 오차: 0.7652
# 496의 평균 절대 오차: 0.6914
# 496의 R-squared: 0.9986
# 497의 평균 제곱 오차: 1.0277
# 497의 평균 절대 오차: 0.6629
# 497의 R-squared: 0.9981
# 498의 평균 제곱 오차: 1.1284
# 498의 평균 절대 오차: 0.7145
# 498의 R-squared: 0.9979
# 499의 평균 제곱 오차: 1.1896
# 499의 평균 절대 오차: 0.7845
# 499의 R-squared: 0.9978
# 500의 평균 제곱 오차: 0.8632
# 500의 평균 절대 오차: 0.5564
# 500의 R-squared: 0.9984
# 501의 평균 제곱 오차: 0.2645
# 501의 평균 절대 오차: 0.4578
# 501의 R-squared: 0.9995
# 502의 평균 제곱 오차: 0.4720
# 502의 평균 절대 오차: 0.5820
# 502의 R-squared: 0.9991
# 503의 평균 제곱 오차: 2.1388
# 503의 평균 절대 오차: 0.9108
# 503의 R-squared: 0.9960
# 504의 평균 제곱 오차: 1.3999
# 504의 평균 절대 오차: 0.8325
# 504의 R-squared: 0.9974
# 505의 평균 제곱 오차: 1.1002
# 505의 평균 절대 오차: 0.7241
# 505의 R-squared: 0.9979
# 506의 평균 제곱 오차: 0.5642
# 506의 평균 절대 오차: 0.5123
# 506의 R-squared: 0.9989
# 507의 평균 제곱 오차: 0.5930
# 507의 평균 절대 오차: 0.6757
# 507의 R-squared: 0.9989
# 508의 평균 제곱 오차: 0.5492
# 508의 평균 절대 오차: 0.6048
# 508의 R-squared: 0.9990
# 509의 평균 제곱 오차: 0.4559
# 509의 평균 절대 오차: 0.5891
# 509의 R-squared: 0.9991
# 510의 평균 제곱 오차: 0.5068
# 510의 평균 절대 오차: 0.6068
# 510의 R-squared: 0.9991
# 511의 평균 제곱 오차: 0.4284
# 511의 평균 절대 오차: 0.5286
# 511의 R-squared: 0.9992
# 512의 평균 제곱 오차: 0.2974
# 512의 평균 절대 오차: 0.4252
# 512의 R-squared: 0.9994
# 513의 평균 제곱 오차: 3.3489
# 513의 평균 절대 오차: 1.1674
# 513의 R-squared: 0.9938
# 514의 평균 제곱 오차: 0.3874
# 514의 평균 절대 오차: 0.5617
# 514의 R-squared: 0.9993
# 515의 평균 제곱 오차: 1.2284
# 515의 평균 절대 오차: 0.8460
# 515의 R-squared: 0.9977
# 516의 평균 제곱 오차: 0.9378
# 516의 평균 절대 오차: 0.8102
# 516의 R-squared: 0.9983
# 517의 평균 제곱 오차: 1.2739
# 517의 평균 절대 오차: 0.8583
# 517의 R-squared: 0.9976
# 518의 평균 제곱 오차: 0.9077
# 518의 평균 절대 오차: 0.7041
# 518의 R-squared: 0.9983
# 519의 평균 제곱 오차: 2.6533
# 519의 평균 절대 오차: 1.0494
# 519의 R-squared: 0.9951
# 520의 평균 제곱 오차: 0.1472
# 520의 평균 절대 오차: 0.3320
# 520의 R-squared: 0.9997
# 521의 평균 제곱 오차: 0.8810
# 521의 평균 절대 오차: 0.7082
# 521의 R-squared: 0.9984
# 522의 평균 제곱 오차: 1.3017
# 522의 평균 절대 오차: 0.7706
# 522의 R-squared: 0.9976
# 523의 평균 제곱 오차: 0.3717
# 523의 평균 절대 오차: 0.5335
# 523의 R-squared: 0.9993
# 524의 평균 제곱 오차: 0.4614
# 524의 평균 절대 오차: 0.5215
# 524의 R-squared: 0.9991
# 525의 평균 제곱 오차: 0.2150
# 525의 평균 절대 오차: 0.3248
# 525의 R-squared: 0.9996
# 526의 평균 제곱 오차: 0.6197
# 526의 평균 절대 오차: 0.6103
# 526의 R-squared: 0.9988
# 527의 평균 제곱 오차: 1.6080
# 527의 평균 절대 오차: 0.9082
# 527의 R-squared: 0.9970
# 528의 평균 제곱 오차: 1.1052
# 528의 평균 절대 오차: 0.6457
# 528의 R-squared: 0.9979
# 529의 평균 제곱 오차: 1.4040
# 529의 평균 절대 오차: 0.8614
# 529의 R-squared: 0.9974
# 530의 평균 제곱 오차: 0.9545
# 530의 평균 절대 오차: 0.8532
# 530의 R-squared: 0.9982
# 531의 평균 제곱 오차: 0.6288
# 531의 평균 절대 오차: 0.6985
# 531의 R-squared: 0.9988
# 532의 평균 제곱 오차: 0.8979
# 532의 평균 절대 오차: 0.6650
# 532의 R-squared: 0.9983
# 533의 평균 제곱 오차: 0.5834
# 533의 평균 절대 오차: 0.6604
# 533의 R-squared: 0.9989
# 534의 평균 제곱 오차: 0.7596
# 534의 평균 절대 오차: 0.6887
# 534의 R-squared: 0.9986
# 535의 평균 제곱 오차: 1.2179
# 535의 평균 절대 오차: 0.7795
# 535의 R-squared: 0.9977
# 536의 평균 제곱 오차: 0.9259
# 536의 평균 절대 오차: 0.7009
# 536의 R-squared: 0.9983
# 537의 평균 제곱 오차: 0.2264
# 537의 평균 절대 오차: 0.3975
# 537의 R-squared: 0.9996
# 538의 평균 제곱 오차: 0.6121
# 538의 평균 절대 오차: 0.5915
# 538의 R-squared: 0.9989
# 539의 평균 제곱 오차: 0.7498
# 539의 평균 절대 오차: 0.5641
# 539의 R-squared: 0.9986
# 540의 평균 제곱 오차: 0.5230
# 540의 평균 절대 오차: 0.6073
# 540의 R-squared: 0.9990
# 541의 평균 제곱 오차: 0.7832
# 541의 평균 절대 오차: 0.7135
# 541의 R-squared: 0.9985
# 542의 평균 제곱 오차: 1.2889
# 542의 평균 절대 오차: 0.7765
# 542의 R-squared: 0.9976
# 543의 평균 제곱 오차: 0.5481
# 543의 평균 절대 오차: 0.6049
# 543의 R-squared: 0.9990
# 544의 평균 제곱 오차: 0.2976
# 544의 평균 절대 오차: 0.4871
# 544의 R-squared: 0.9994
# 545의 평균 제곱 오차: 0.6543
# 545의 평균 절대 오차: 0.6437
# 545의 R-squared: 0.9988
# 546의 평균 제곱 오차: 0.5818
# 546의 평균 절대 오차: 0.5637
# 546의 R-squared: 0.9989
# 547의 평균 제곱 오차: 0.5402
# 547의 평균 절대 오차: 0.5165
# 547의 R-squared: 0.9990
# 548의 평균 제곱 오차: 0.6795
# 548의 평균 절대 오차: 0.6120
# 548의 R-squared: 0.9987
# 549의 평균 제곱 오차: 0.7184
# 549의 평균 절대 오차: 0.6225
# 549의 R-squared: 0.9987
# 550의 평균 제곱 오차: 0.4779
# 550의 평균 절대 오차: 0.5848
# 550의 R-squared: 0.9991
# 551의 평균 제곱 오차: 0.4063
# 551의 평균 절대 오차: 0.5195
# 551의 R-squared: 0.9992
# 552의 평균 제곱 오차: 1.1956
# 552의 평균 절대 오차: 0.7954
# 552의 R-squared: 0.9978
# 553의 평균 제곱 오차: 0.7927
# 553의 평균 절대 오차: 0.6983
# 553의 R-squared: 0.9985
# 554의 평균 제곱 오차: 0.5740
# 554의 평균 절대 오차: 0.6084
# 554의 R-squared: 0.9989
# 555의 평균 제곱 오차: 0.7310
# 555의 평균 절대 오차: 0.6933
# 555의 R-squared: 0.9986
# 556의 평균 제곱 오차: 0.5837
# 556의 평균 절대 오차: 0.6488
# 556의 R-squared: 0.9989
# 557의 평균 제곱 오차: 0.6314
# 557의 평균 절대 오차: 0.6169
# 557의 R-squared: 0.9988
# 558의 평균 제곱 오차: 0.6801
# 558의 평균 절대 오차: 0.6491
# 558의 R-squared: 0.9987
# 559의 평균 제곱 오차: 0.3632
# 559의 평균 절대 오차: 0.5358
# 559의 R-squared: 0.9993
# 560의 평균 제곱 오차: 0.5352
# 560의 평균 절대 오차: 0.6145
# 560의 R-squared: 0.9990
# 561의 평균 제곱 오차: 0.4195
# 561의 평균 절대 오차: 0.5085
# 561의 R-squared: 0.9992
# 562의 평균 제곱 오차: 0.4436
# 562의 평균 절대 오차: 0.5684
# 562의 R-squared: 0.9992
# 563의 평균 제곱 오차: 0.4353
# 563의 평균 절대 오차: 0.5648
# 563의 R-squared: 0.9992
# 564의 평균 제곱 오차: 1.0887
# 564의 평균 절대 오차: 0.7293
# 564의 R-squared: 0.9980
# 565의 평균 제곱 오차: 3.6053
# 565의 평균 절대 오차: 1.2246
# 565의 R-squared: 0.9933
# 566의 평균 제곱 오차: 1.1484
# 566의 평균 절대 오차: 0.8048
# 566의 R-squared: 0.9979
# 567의 평균 제곱 오차: 0.6580
# 567의 평균 절대 오차: 0.6841
# 567의 R-squared: 0.9988
# 568의 평균 제곱 오차: 2.0092
# 568의 평균 절대 오차: 0.8795
# 568의 R-squared: 0.9963
# 569의 평균 제곱 오차: 0.4281
# 569의 평균 절대 오차: 0.5563
# 569의 R-squared: 0.9992
# 570의 평균 제곱 오차: 0.5757
# 570의 평균 절대 오차: 0.6052
# 570의 R-squared: 0.9989
# 571의 평균 제곱 오차: 3.4605
# 571의 평균 절대 오차: 1.1792
# 571의 R-squared: 0.9935
# 572의 평균 제곱 오차: 0.4418
# 572의 평균 절대 오차: 0.5481
# 572의 R-squared: 0.9992
# 573의 평균 제곱 오차: 1.1664
# 573의 평균 절대 오차: 0.7613
# 573의 R-squared: 0.9978
# 574의 평균 제곱 오차: 3.5151
# 574의 평균 절대 오차: 1.1743
# 574의 R-squared: 0.9934
# 575의 평균 제곱 오차: 0.9134
# 575의 평균 절대 오차: 0.8508
# 575의 R-squared: 0.9983
# 576의 평균 제곱 오차: 3.7085
# 576의 평균 절대 오차: 1.2555
# 576의 R-squared: 0.9931
# 577의 평균 제곱 오차: 4.5688
# 577의 평균 절대 오차: 1.2805
# 577의 R-squared: 0.9915
# 578의 평균 제곱 오차: 0.7975
# 578의 평균 절대 오차: 0.7690
# 578의 R-squared: 0.9985
# 579의 평균 제곱 오차: 3.5250
# 579의 평균 절대 오차: 1.2028
# 579의 R-squared: 0.9934
# 580의 평균 제곱 오차: 0.4598
# 580의 평균 절대 오차: 0.5293
# 580의 R-squared: 0.9991
# 581의 평균 제곱 오차: 2.6538
# 581의 평균 절대 오차: 1.1915
# 581의 R-squared: 0.9951
# 582의 평균 제곱 오차: 2.6019
# 582의 평균 절대 오차: 1.0425
# 582의 R-squared: 0.9951
# 583의 평균 제곱 오차: 2.9208
# 583의 평균 절대 오차: 1.2117
# 583의 R-squared: 0.9946
# 584의 평균 제곱 오차: 3.4665
# 584의 평균 절대 오차: 1.0860
# 584의 R-squared: 0.9935
# 585의 평균 제곱 오차: 0.7224
# 585의 평균 절대 오차: 0.5979
# 585의 R-squared: 0.9987
# 586의 평균 제곱 오차: 3.4028
# 586의 평균 절대 오차: 1.1190
# 586의 R-squared: 0.9937
# 587의 평균 제곱 오차: 3.8658
# 587의 평균 절대 오차: 1.3751
# 587의 R-squared: 0.9928
# 588의 평균 제곱 오차: 1.6625
# 588의 평균 절대 오차: 0.9488
# 588의 R-squared: 0.9969
# 589의 평균 제곱 오차: 3.6115
# 589의 평균 절대 오차: 1.3194
# 589의 R-squared: 0.9933
# 590의 평균 제곱 오차: 3.6692
# 590의 평균 절대 오차: 1.1125
# 590의 R-squared: 0.9932
# 591의 평균 제곱 오차: 3.5571
# 591의 평균 절대 오차: 1.1579
# 591의 R-squared: 0.9934
# 592의 평균 제곱 오차: 3.6008
# 592의 평균 절대 오차: 1.1773
# 592의 R-squared: 0.9933
# 593의 평균 제곱 오차: 3.6403
# 593의 평균 절대 오차: 1.2111
# 593의 R-squared: 0.9932
# 594의 평균 제곱 오차: 3.8618
# 594의 평균 절대 오차: 1.2222
# 594의 R-squared: 0.9928
# 595의 평균 제곱 오차: 0.5581
# 595의 평균 절대 오차: 0.6452
# 595의 R-squared: 0.9990
# 596의 평균 제곱 오차: 2.0630
# 596의 평균 절대 오차: 0.9127
# 596의 R-squared: 0.9962
# 597의 평균 제곱 오차: 2.8500
# 597의 평균 절대 오차: 1.2356
# 597의 R-squared: 0.9947
# 598의 평균 제곱 오차: 2.0223
# 598의 평균 절대 오차: 1.0876
# 598의 R-squared: 0.9962
# 599의 평균 제곱 오차: 0.5779
# 599의 평균 절대 오차: 0.6135
# 599의 R-squared: 0.9989
# 600의 평균 제곱 오차: 3.0742
# 600의 평균 절대 오차: 1.1801
# 600의 R-squared: 0.9943
# 601의 평균 제곱 오차: 2.3541
# 601의 평균 절대 오차: 0.9393
# 601의 R-squared: 0.9956
# 602의 평균 제곱 오차: 2.7715
# 602의 평균 절대 오차: 1.1736
# 602의 R-squared: 0.9948
# 603의 평균 제곱 오차: 2.4109
# 603의 평균 절대 오차: 1.1481
# 603의 R-squared: 0.9955
# 604의 평균 제곱 오차: 0.3998
# 604의 평균 절대 오차: 0.5332
# 604의 R-squared: 0.9993
# 605의 평균 제곱 오차: 2.1318
# 605의 평균 절대 오차: 0.9821
# 605의 R-squared: 0.9960
# 606의 평균 제곱 오차: 0.3301
# 606의 평균 절대 오차: 0.4787
# 606의 R-squared: 0.9994
# 607의 평균 제곱 오차: 0.6132
# 607의 평균 절대 오차: 0.5147
# 607의 R-squared: 0.9989
# 608의 평균 제곱 오차: 0.6849
# 608의 평균 절대 오차: 0.6442
# 608의 R-squared: 0.9987
# 609의 평균 제곱 오차: 0.6043
# 609의 평균 절대 오차: 0.5860
# 609의 R-squared: 0.9989
# 610의 평균 제곱 오차: 0.9316
# 610의 평균 절대 오차: 0.8199
# 610의 R-squared: 0.9983
# 611의 평균 제곱 오차: 0.8329
# 611의 평균 절대 오차: 0.6401
# 611의 R-squared: 0.9984
# 612의 평균 제곱 오차: 1.4104
# 612의 평균 절대 오차: 0.8679
# 612의 R-squared: 0.9974
# 613의 평균 제곱 오차: 1.3825
# 613의 평균 절대 오차: 0.7161
# 613의 R-squared: 0.9974
# 614의 평균 제곱 오차: 3.0074
# 614의 평균 절대 오차: 1.1925
# 614의 R-squared: 0.9944
# 615의 평균 제곱 오차: 3.6604
# 615의 평균 절대 오차: 1.2447
# 615의 R-squared: 0.9932
# 616의 평균 제곱 오차: 2.3416
# 616의 평균 절대 오차: 1.1801
# 616의 R-squared: 0.9956
# 617의 평균 제곱 오차: 2.1733
# 617의 평균 절대 오차: 0.9612
# 617의 R-squared: 0.9959
# 618의 평균 제곱 오차: 3.3667
# 618의 평균 절대 오차: 1.1727
# 618의 R-squared: 0.9937
# 619의 평균 제곱 오차: 2.3983
# 619의 평균 절대 오차: 0.9780
# 619의 R-squared: 0.9955
# 620의 평균 제곱 오차: 3.6529
# 620의 평균 절대 오차: 1.3159
# 620의 R-squared: 0.9932
# 621의 평균 제곱 오차: 3.7018
# 621의 평균 절대 오차: 1.2685
# 621의 R-squared: 0.9931
# 622의 평균 제곱 오차: 3.3273
# 622의 평균 절대 오차: 1.1476
# 622의 R-squared: 0.9938
# 623의 평균 제곱 오차: 3.7688
# 623의 평균 절대 오차: 1.2812
# 623의 R-squared: 0.9930
# 624의 평균 제곱 오차: 3.5530
# 624의 평균 절대 오차: 1.1696
# 624의 R-squared: 0.9934
# 625의 평균 제곱 오차: 4.8791
# 625의 평균 절대 오차: 1.4828
# 625의 R-squared: 0.9909
# 626의 평균 제곱 오차: 5.1229
# 626의 평균 절대 오차: 1.4047
# 626의 R-squared: 0.9904
# 627의 평균 제곱 오차: 3.7479
# 627의 평균 절대 오차: 1.2768
# 627의 R-squared: 0.9930
# 628의 평균 제곱 오차: 5.0091
# 628의 평균 절대 오차: 1.5225
# 628의 R-squared: 0.9907
# 629의 평균 제곱 오차: 1.8673
# 629의 평균 절대 오차: 0.9310
# 629의 R-squared: 0.9965
# 630의 평균 제곱 오차: 3.7672
# 630의 평균 절대 오차: 1.2957
# 630의 R-squared: 0.9930
# 631의 평균 제곱 오차: 4.6419
# 631의 평균 절대 오차: 1.3316
# 631의 R-squared: 0.9913
# 632의 평균 제곱 오차: 3.8390
# 632의 평균 절대 오차: 1.2971
# 632의 R-squared: 0.9928
# 633의 평균 제곱 오차: 4.7398
# 633의 평균 절대 오차: 1.3104
# 633의 R-squared: 0.9912
# 634의 평균 제곱 오차: 5.0995
# 634의 평균 절대 오차: 1.5239
# 634의 R-squared: 0.9905
# 635의 평균 제곱 오차: 3.8857
# 635의 평균 절대 오차: 1.2535
# 635의 R-squared: 0.9928
# 636의 평균 제곱 오차: 3.6144
# 636의 평균 절대 오차: 1.2680
# 636의 R-squared: 0.9933
# 637의 평균 제곱 오차: 5.1417
# 637의 평균 절대 오차: 1.5253
# 637의 R-squared: 0.9904
# 638의 평균 제곱 오차: 2.5347
# 638의 평균 절대 오차: 1.0188
# 638의 R-squared: 0.9953
# 639의 평균 제곱 오차: 3.0530
# 639의 평균 절대 오차: 1.3098
# 639의 R-squared: 0.9943
# 640의 평균 제곱 오차: 3.6263
# 640의 평균 절대 오차: 1.2369
# 640의 R-squared: 0.9932
# 641의 평균 제곱 오차: 1.8566
# 641의 평균 절대 오차: 0.8923
# 641의 R-squared: 0.9965
# 642의 평균 제곱 오차: 0.5874
# 642의 평균 절대 오차: 0.5762
# 642의 R-squared: 0.9989
# 643의 평균 제곱 오차: 2.7952
# 643의 평균 절대 오차: 1.1980
# 643의 R-squared: 0.9948
# 644의 평균 제곱 오차: 5.5448
# 644의 평균 절대 오차: 1.5528
# 644의 R-squared: 0.9897
# 645의 평균 제곱 오차: 3.6406
# 645의 평균 절대 오차: 1.1891
# 645의 R-squared: 0.9932
# 646의 평균 제곱 오차: 4.7194
# 646의 평균 절대 오차: 1.3572
# 646의 R-squared: 0.9912
# 647의 평균 제곱 오차: 2.7807
# 647의 평균 절대 오차: 1.0724
# 647의 R-squared: 0.9948
# 648의 평균 제곱 오차: 3.4291
# 648의 평균 절대 오차: 1.0700
# 648의 R-squared: 0.9936
# 649의 평균 제곱 오차: 4.0429
# 649의 평균 절대 오차: 1.3792
# 649의 R-squared: 0.9925
# 650의 평균 제곱 오차: 4.8965
# 650의 평균 절대 오차: 1.3835
# 650의 R-squared: 0.9909
# 651의 평균 제곱 오차: 0.1685
# 651의 평균 절대 오차: 0.3248
# 651의 R-squared: 0.9997
# 652의 평균 제곱 오차: 2.1876
# 652의 평균 절대 오차: 1.1134
# 652의 R-squared: 0.9959
# 653의 평균 제곱 오차: 1.2942
# 653의 평균 절대 오차: 0.8516
# 653의 R-squared: 0.9976
# 654의 평균 제곱 오차: 2.6895
# 654의 평균 절대 오차: 1.0942
# 654의 R-squared: 0.9950
# 655의 평균 제곱 오차: 2.4011
# 655의 평균 절대 오차: 0.9745
# 655의 R-squared: 0.9955
# 656의 평균 제곱 오차: 2.2351
# 656의 평균 절대 오차: 0.9437
# 656의 R-squared: 0.9958
# 657의 평균 제곱 오차: 2.6080
# 657의 평균 절대 오차: 1.0704
# 657의 R-squared: 0.9951
# 658의 평균 제곱 오차: 3.6592
# 658의 평균 절대 오차: 1.3652
# 658의 R-squared: 0.9932
# 659의 평균 제곱 오차: 1.0637
# 659의 평균 절대 오차: 0.7368
# 659의 R-squared: 0.9980
# 660의 평균 제곱 오차: 3.7496
# 660의 평균 절대 오차: 1.3126
# 660의 R-squared: 0.9930
# 661의 평균 제곱 오차: 2.6823
# 661의 평균 절대 오차: 1.1592
# 661의 R-squared: 0.9950
# 662의 평균 제곱 오차: 4.9699
# 662의 평균 절대 오차: 1.4573
# 662의 R-squared: 0.9907
# 663의 평균 제곱 오차: 2.8862
# 663의 평균 절대 오차: 1.1101
# 663의 R-squared: 0.9946
# 664의 평균 제곱 오차: 3.7252
# 664의 평균 절대 오차: 1.2906
# 664의 R-squared: 0.9931
# 665의 평균 제곱 오차: 3.2558
# 665의 평균 절대 오차: 1.0279
# 665의 R-squared: 0.9939
# 666의 평균 제곱 오차: 3.8497
# 666의 평균 절대 오차: 1.2549
# 666의 R-squared: 0.9928
# 667의 평균 제곱 오차: 3.6611
# 667의 평균 절대 오차: 1.1238
# 667의 R-squared: 0.9932
# 668의 평균 제곱 오차: 0.7785
# 668의 평균 절대 오차: 0.7186
# 668의 R-squared: 0.9985
# 669의 평균 제곱 오차: 2.7034
# 669의 평균 절대 오차: 1.0070
# 669의 R-squared: 0.9950
# 670의 평균 제곱 오차: 3.5824
# 670의 평균 절대 오차: 1.2509
# 670의 R-squared: 0.9933
# 671의 평균 제곱 오차: 2.9437
# 671의 평균 절대 오차: 1.1545
# 671의 R-squared: 0.9945
# 672의 평균 제곱 오차: 3.8085
# 672의 평균 절대 오차: 1.3896
# 672의 R-squared: 0.9929
# 673의 평균 제곱 오차: 2.7631
# 673의 평균 절대 오차: 1.1299
# 673의 R-squared: 0.9948
# 674의 평균 제곱 오차: 2.7895
# 674의 평균 절대 오차: 1.0405
# 674의 R-squared: 0.9948
# 675의 평균 제곱 오차: 2.7060
# 675의 평균 절대 오차: 1.0738
# 675의 R-squared: 0.9950
# 676의 평균 제곱 오차: 3.9934
# 676의 평균 절대 오차: 1.2943
# 676의 R-squared: 0.9926
# 677의 평균 제곱 오차: 6.1760
# 677의 평균 절대 오차: 1.6833
# 677의 R-squared: 0.9885
# 678의 평균 제곱 오차: 1.9446
# 678의 평균 절대 오차: 0.9987
# 678의 R-squared: 0.9964
# 679의 평균 제곱 오차: 4.1822
# 679의 평균 절대 오차: 1.3047
# 679의 R-squared: 0.9922
# 680의 평균 제곱 오차: 3.7170
# 680의 평균 절대 오차: 1.1446
# 680의 R-squared: 0.9931
# 681의 평균 제곱 오차: 4.5739
# 681의 평균 절대 오차: 1.2148
# 681의 R-squared: 0.9915
# 682의 평균 제곱 오차: 3.6334
# 682의 평균 절대 오차: 1.1876
# 682의 R-squared: 0.9932
# 683의 평균 제곱 오차: 4.0801
# 683의 평균 절대 오차: 1.3365
# 683의 R-squared: 0.9924
# 684의 평균 제곱 오차: 4.0272
# 684의 평균 절대 오차: 1.5016
# 684의 R-squared: 0.9925
# 685의 평균 제곱 오차: 1.1131
# 685의 평균 절대 오차: 0.7849
# 685의 R-squared: 0.9979
# 686의 평균 제곱 오차: 2.7555
# 686의 평균 절대 오차: 1.1767
# 686의 R-squared: 0.9949
# 687의 평균 제곱 오차: 2.8995
# 687의 평균 절대 오차: 1.1835
# 687의 R-squared: 0.9946
# 688의 평균 제곱 오차: 1.4942
# 688의 평균 절대 오차: 0.9731
# 688의 R-squared: 0.9972
# 689의 평균 제곱 오차: 0.3712
# 689의 평균 절대 오차: 0.4747
# 689의 R-squared: 0.9993
# 690의 평균 제곱 오차: 1.9958
# 690의 평균 절대 오차: 0.9837
# 690의 R-squared: 0.9963
# 691의 평균 제곱 오차: 0.8146
# 691의 평균 절대 오차: 0.7753
# 691의 R-squared: 0.9985
# 692의 평균 제곱 오차: 0.2896
# 692의 평균 절대 오차: 0.4645
# 692의 R-squared: 0.9995
# 694의 평균 제곱 오차: 0.4698
# 694의 평균 절대 오차: 0.5354
# 694의 R-squared: 0.9991
# 695의 평균 제곱 오차: 0.5893
# 695의 평균 절대 오차: 0.6030
# 695의 R-squared: 0.9989
# 696의 평균 제곱 오차: 0.6571
# 696의 평균 절대 오차: 0.5588
# 696의 R-squared: 0.9988
# 697의 평균 제곱 오차: 0.3634
# 697의 평균 절대 오차: 0.5308
# 697의 R-squared: 0.9993
# 699의 평균 제곱 오차: 0.5639
# 699의 평균 절대 오차: 0.5903
# 699의 R-squared: 0.9989
# 701의 평균 제곱 오차: 0.6717
# 701의 평균 절대 오차: 0.6552
# 701의 R-squared: 0.9987
# 703의 평균 제곱 오차: 0.8043
# 703의 평균 절대 오차: 0.6867
# 703의 R-squared: 0.9985
# 704의 평균 제곱 오차: 0.4431
# 704의 평균 절대 오차: 0.5092
# 704의 R-squared: 0.9992
# 705의 평균 제곱 오차: 0.4774
# 705의 평균 절대 오차: 0.5816
# 705의 R-squared: 0.9991
# 706의 평균 제곱 오차: 1.0901
# 706의 평균 절대 오차: 0.8669
# 706의 R-squared: 0.9980
# 707의 평균 제곱 오차: 0.3071
# 707의 평균 절대 오차: 0.3865
# 707의 R-squared: 0.9994
# 708의 평균 제곱 오차: 0.3665
# 708의 평균 절대 오차: 0.5063
# 708의 R-squared: 0.9993
# 709의 평균 제곱 오차: 1.1845
# 709의 평균 절대 오차: 0.7495
# 709의 R-squared: 0.9978
# 710의 평균 제곱 오차: 0.2660
# 710의 평균 절대 오차: 0.4733
# 710의 R-squared: 0.9995
# 711의 평균 제곱 오차: 1.0568
# 711의 평균 절대 오차: 0.6722
# 711의 R-squared: 0.9980
# 712의 평균 제곱 오차: 2.6033
# 712의 평균 절대 오차: 1.0885
# 712의 R-squared: 0.9951
# 713의 평균 제곱 오차: 1.2651
# 713의 평균 절대 오차: 0.8469
# 713의 R-squared: 0.9976
# 714의 평균 제곱 오차: 3.1768
# 714의 평균 절대 오차: 1.1922
# 714의 R-squared: 0.9941
# 715의 평균 제곱 오차: 0.6468
# 715의 평균 절대 오차: 0.6843
# 715의 R-squared: 0.9988
# 716의 평균 제곱 오차: 1.2540
# 716의 평균 절대 오차: 0.8012
# 716의 R-squared: 0.9977
# 717의 평균 제곱 오차: 1.0878
# 717의 평균 절대 오차: 0.7688
# 717의 R-squared: 0.9980
# 718의 평균 제곱 오차: 2.2870
# 718의 평균 절대 오차: 1.0900
# 718의 R-squared: 0.9957
# 719의 평균 제곱 오차: 3.9001
# 719의 평균 절대 오차: 1.2976
# 719의 R-squared: 0.9927
# 720의 평균 제곱 오차: 0.6803
# 720의 평균 절대 오차: 0.7297
# 720의 R-squared: 0.9987
# 721의 평균 제곱 오차: 1.2970
# 721의 평균 절대 오차: 0.8990
# 721의 R-squared: 0.9976
# 722의 평균 제곱 오차: 0.7853
# 722의 평균 절대 오차: 0.7248
# 722의 R-squared: 0.9985
# 723의 평균 제곱 오차: 1.0812
# 723의 평균 절대 오차: 0.7359
# 723의 R-squared: 0.9980
# 724의 평균 제곱 오차: 0.8256
# 724의 평균 절대 오차: 0.6578
# 724의 R-squared: 0.9985
# 725의 평균 제곱 오차: 0.4367
# 725의 평균 절대 오차: 0.5604
# 725의 R-squared: 0.9992
# 727의 평균 제곱 오차: 0.6640
# 727의 평균 절대 오차: 0.6822
# 727의 R-squared: 0.9988
# 730의 평균 제곱 오차: 1.2405
# 730의 평균 절대 오차: 0.8114
# 730의 R-squared: 0.9977
# 731의 평균 제곱 오차: 0.6039
# 731의 평균 절대 오차: 0.6219
# 731의 R-squared: 0.9989
# 732의 평균 제곱 오차: 0.6206
# 732의 평균 절대 오차: 0.6466
# 732의 R-squared: 0.9988
# 733의 평균 제곱 오차: 0.5336
# 733의 평균 절대 오차: 0.6009
# 733의 R-squared: 0.9990
# 734의 평균 제곱 오차: 0.4204
# 734의 평균 절대 오차: 0.5124
# 734의 R-squared: 0.9992
# 735의 평균 제곱 오차: 1.0193
# 735의 평균 절대 오차: 0.8410
# 735의 R-squared: 0.9981
# 736의 평균 제곱 오차: 0.5467
# 736의 평균 절대 오차: 0.6053
# 736의 R-squared: 0.9990
# 737의 평균 제곱 오차: 1.2151
# 737의 평균 절대 오차: 0.9787
# 737의 R-squared: 0.9977
# 738의 평균 제곱 오차: 0.4359
# 738의 평균 절대 오차: 0.5848
# 738의 R-squared: 0.9992
# 739의 평균 제곱 오차: 0.9638
# 739의 평균 절대 오차: 0.7868
# 739의 R-squared: 0.9982
# 740의 평균 제곱 오차: 0.6140
# 740의 평균 절대 오차: 0.5435
# 740의 R-squared: 0.9989
# 741의 평균 제곱 오차: 0.9327
# 741의 평균 절대 오차: 0.6143
# 741의 R-squared: 0.9983
# 742의 평균 제곱 오차: 0.5407
# 742의 평균 절대 오차: 0.6322
# 742의 R-squared: 0.9990
# 743의 평균 제곱 오차: 2.7297
# 743의 평균 절대 오차: 1.1447
# 743의 R-squared: 0.9949
# 744의 평균 제곱 오차: 0.5610
# 744의 평균 절대 오차: 0.5543
# 744의 R-squared: 0.9990
# 745의 평균 제곱 오차: 0.7705
# 745의 평균 절대 오차: 0.6906
# 745의 R-squared: 0.9986
# 746의 평균 제곱 오차: 0.5990
# 746의 평균 절대 오차: 0.6354
# 746의 R-squared: 0.9989
# 747의 평균 제곱 오차: 0.6533
# 747의 평균 절대 오차: 0.6116
# 747의 R-squared: 0.9988
# 748의 평균 제곱 오차: 0.8056
# 748의 평균 절대 오차: 0.7393
# 748의 R-squared: 0.9985
# 749의 평균 제곱 오차: 0.5477
# 749의 평균 절대 오차: 0.5517
# 749의 R-squared: 0.9990
# 750의 평균 제곱 오차: 1.0513
# 750의 평균 절대 오차: 0.9219
# 750의 R-squared: 0.9980
# 751의 평균 제곱 오차: 0.3924
# 751의 평균 절대 오차: 0.5141
# 751의 R-squared: 0.9993
# 752의 평균 제곱 오차: 0.5441
# 752의 평균 절대 오차: 0.5822
# 752의 R-squared: 0.9990
# 753의 평균 제곱 오차: 0.9321
# 753의 평균 절대 오차: 0.8384
# 753의 R-squared: 0.9983
# 754의 평균 제곱 오차: 0.3715
# 754의 평균 절대 오차: 0.5043
# ...
# 870의 R-squared: 0.9995
# 871의 평균 제곱 오차: 0.7633
# 871의 평균 절대 오차: 0.7592
# 871의 R-squared: 0.9986
# 872의 평균 제곱 오차: 0.6515
# 872의 평균 절대 오차: 0.6963
# 872의 R-squared: 0.9988
# 873의 평균 제곱 오차: 0.5379
# 873의 평균 절대 오차: 0.6322
# 873의 R-squared: 0.9990
# 874의 평균 제곱 오차: 1.0337
# 874의 평균 절대 오차: 0.6512
# 874의 R-squared: 0.9981
# 875의 평균 제곱 오차: 0.5991
# 875의 평균 절대 오차: 0.6149
# 875의 R-squared: 0.9989
# 876의 평균 제곱 오차: 1.0800
# 876의 평균 절대 오차: 0.7141
# 876의 R-squared: 0.9980
# 877의 평균 제곱 오차: 1.9939
# 877의 평균 절대 오차: 1.0491
# 877의 R-squared: 0.9963
# 878의 평균 제곱 오차: 0.8628
# 878의 평균 절대 오차: 0.7917
# 878의 R-squared: 0.9984
# 879의 평균 제곱 오차: 0.5309
# 879의 평균 절대 오차: 0.5632
# 879의 R-squared: 0.9990
# 880의 평균 제곱 오차: 0.8462
# 880의 평균 절대 오차: 0.8235
# 880의 R-squared: 0.9984
# 884의 평균 제곱 오차: 3.1298
# 884의 평균 절대 오차: 1.2689
# 884의 R-squared: 0.9942
# 885의 평균 제곱 오차: 3.9642
# 885의 평균 절대 오차: 1.4217
# 885의 R-squared: 0.9926
# 886의 평균 제곱 오차: 1.5741
# 886의 평균 절대 오차: 0.9790
# 886의 R-squared: 0.9971
# 887의 평균 제곱 오차: 1.3391
# 887의 평균 절대 오차: 0.8763
# 887의 R-squared: 0.9975
# 888의 평균 제곱 오차: 1.7196
# 888의 평균 절대 오차: 1.0443
# 888의 R-squared: 0.9968
# 926의 평균 제곱 오차: 0.8981
# 926의 평균 절대 오차: 0.8391
# 926의 R-squared: 0.9983
# 927의 평균 제곱 오차: 0.3261
# 927의 평균 절대 오차: 0.4803
# 927의 R-squared: 0.9994
# 928의 평균 제곱 오차: 0.7790
# 928의 평균 절대 오차: 0.6204
# 928의 R-squared: 0.9985
# 929의 평균 제곱 오차: 0.2826
# 929의 평균 절대 오차: 0.4064
# 929의 R-squared: 0.9995
# 930의 평균 제곱 오차: 0.6037
# 930의 평균 절대 오차: 0.5769
# 930의 R-squared: 0.9989
# 931의 평균 제곱 오차: 0.3821
# 931의 평균 절대 오차: 0.5320
# 931의 R-squared: 0.9993
# 932의 평균 제곱 오차: 0.4732
# 932의 평균 절대 오차: 0.5484
# 932의 R-squared: 0.9991
# 933의 평균 제곱 오차: 0.4675
# 933의 평균 절대 오차: 0.5795
# 933의 R-squared: 0.9991
# 934의 평균 제곱 오차: 0.6446
# 934의 평균 절대 오차: 0.7369
# 934의 R-squared: 0.9988
# 935의 평균 제곱 오차: 0.7992
# 935의 평균 절대 오차: 0.6578
# 935의 R-squared: 0.9985
# 936의 평균 제곱 오차: 0.6861
# 936의 평균 절대 오차: 0.7324
# 936의 R-squared: 0.9987
# 937의 평균 제곱 오차: 1.6110
# 937의 평균 절대 오차: 0.9840
# 937의 R-squared: 0.9970
# 938의 평균 제곱 오차: 0.4595
# 938의 평균 절대 오차: 0.5430
# 938의 R-squared: 0.9991
# 939의 평균 제곱 오차: 1.1102
# 939의 평균 절대 오차: 0.8484
# 939의 R-squared: 0.9979
# 940의 평균 제곱 오차: 0.6051
# 940의 평균 절대 오차: 0.6423
# 940의 R-squared: 0.9989
# 941의 평균 제곱 오차: 2.4460
# 941의 평균 절대 오차: 1.1611
# 941의 R-squared: 0.9954
# 942의 평균 제곱 오차: 0.7523
# 942의 평균 절대 오차: 0.7402
# 942의 R-squared: 0.9986
# 943의 평균 제곱 오차: 0.8036
# 943의 평균 절대 오차: 0.6566
# 943의 R-squared: 0.9985
# 944의 평균 제곱 오차: 1.6323
# 944의 평균 절대 오차: 0.8724
# 944의 R-squared: 0.9970
# 945의 평균 제곱 오차: 1.6765
# 945의 평균 절대 오차: 0.9158
# 945의 R-squared: 0.9969
# 946의 평균 제곱 오차: 0.9337
# 946의 평균 절대 오차: 0.7301
# 946의 R-squared: 0.9983
# 947의 평균 제곱 오차: 1.3527
# 947의 평균 절대 오차: 0.7921
# 947의 R-squared: 0.9975
# 948의 평균 제곱 오차: 2.5457
# 948의 평균 절대 오차: 0.9819
# 948의 R-squared: 0.9953
# 949의 평균 제곱 오차: 1.5264
# 949의 평균 절대 오차: 0.6044
# 949의 R-squared: 0.9972
# 950의 평균 제곱 오차: 2.6585
# 950의 평균 절대 오차: 1.0518
# 950의 R-squared: 0.9950
# 951의 평균 제곱 오차: 2.5030
# 951의 평균 절대 오차: 0.9395
# 951의 R-squared: 0.9953
# 952의 평균 제곱 오차: 1.3691
# 952의 평균 절대 오차: 0.8844
# 952의 R-squared: 0.9974
# 953의 평균 제곱 오차: 1.9799
# 953의 평균 절대 오차: 1.0384
# 953의 R-squared: 0.9963
# 954의 평균 제곱 오차: 0.4666
# 954의 평균 절대 오차: 0.5428
# 954의 R-squared: 0.9991
# 955의 평균 제곱 오차: 0.3210
# 955의 평균 절대 오차: 0.4628
# 955의 R-squared: 0.9994
# 956의 평균 제곱 오차: 0.2526
# 956의 평균 절대 오차: 0.4383
# 956의 R-squared: 0.9995
# 957의 평균 제곱 오차: 1.8488
# 957의 평균 절대 오차: 0.7887
# 957의 R-squared: 0.9966
# 958의 평균 제곱 오차: 2.7997
# 958의 평균 절대 오차: 1.0039
# 958의 R-squared: 0.9948
# 959의 평균 제곱 오차: 2.6380
# 959의 평균 절대 오차: 0.9954
# 959의 R-squared: 0.9951
# 960의 평균 제곱 오차: 0.6682
# 960의 평균 절대 오차: 0.6585
# 960의 R-squared: 0.9988
# 961의 평균 제곱 오차: 0.8225
# 961의 평균 절대 오차: 0.6184
# 961의 R-squared: 0.9985
# 962의 평균 제곱 오차: 1.2403
# 962의 평균 절대 오차: 0.8351
# 962의 R-squared: 0.9977
# 963의 평균 제곱 오차: 1.4897
# 963의 평균 절대 오차: 0.8358
# 963의 R-squared: 0.9972
# 964의 평균 제곱 오차: 1.2711
# 964의 평균 절대 오차: 0.7337
# 964의 R-squared: 0.9976
# 965의 평균 제곱 오차: 0.6511
# 965의 평균 절대 오차: 0.5314
# 965의 R-squared: 0.9988
# 966의 평균 제곱 오차: 1.5484
# 966의 평균 절대 오차: 0.7358
# 966의 R-squared: 0.9971
# 967의 평균 제곱 오차: 0.6923
# 967의 평균 절대 오차: 0.6529
# 967의 R-squared: 0.9987
# 968의 평균 제곱 오차: 1.0726
# 968의 평균 절대 오차: 0.6354
# 968의 R-squared: 0.9980
# 969의 평균 제곱 오차: 0.7577
# 969의 평균 절대 오차: 0.7215
# 969의 R-squared: 0.9986
# 970의 평균 제곱 오차: 0.3915
# 970의 평균 절대 오차: 0.5548
# 970의 R-squared: 0.9993
# 971의 평균 제곱 오차: 0.7863
# 971의 평균 절대 오차: 0.7078
# 971의 R-squared: 0.9985
# 972의 평균 제곱 오차: 0.7328
# 972의 평균 절대 오차: 0.6126
# 972의 R-squared: 0.9986
# 973의 평균 제곱 오차: 1.0713
# 973의 평균 절대 오차: 0.7277
# 973의 R-squared: 0.9980
# 974의 평균 제곱 오차: 1.4887
# 974의 평균 절대 오차: 0.8211
# 974의 R-squared: 0.9972
# 975의 평균 제곱 오차: 1.7731
# 975의 평균 절대 오차: 0.7986
# 975의 R-squared: 0.9967
# 976의 평균 제곱 오차: 0.2426
# 976의 평균 절대 오차: 0.4284
# 976의 R-squared: 0.9995
# 977의 평균 제곱 오차: 1.2181
# 977의 평균 절대 오차: 0.7051
# 977의 R-squared: 0.9977
# 978의 평균 제곱 오차: 1.3928
# 978의 평균 절대 오차: 0.9116
# 978의 R-squared: 0.9974
# 979의 평균 제곱 오차: 1.5242
# 979의 평균 절대 오차: 0.7057
# 979의 R-squared: 0.9972
# 980의 평균 제곱 오차: 0.9336
# 980의 평균 절대 오차: 0.6956
# 980의 R-squared: 0.9983
# 981의 평균 제곱 오차: 0.8908
# 981의 평균 절대 오차: 0.6769
# 981의 R-squared: 0.9983
# 982의 평균 제곱 오차: 1.0662
# 982의 평균 절대 오차: 0.7924
# 982의 R-squared: 0.9980
# 983의 평균 제곱 오차: 0.2702
# 983의 평균 절대 오차: 0.4740
# 983의 R-squared: 0.9995
# 984의 평균 제곱 오차: 0.3997
# 984의 평균 절대 오차: 0.5440
# 984의 R-squared: 0.9993
# 985의 평균 제곱 오차: 0.4341
# 985의 평균 절대 오차: 0.4607
# 985의 R-squared: 0.9992
# 986의 평균 제곱 오차: 0.4655
# 986의 평균 절대 오차: 0.4841
# 986의 R-squared: 0.9991
# 987의 평균 제곱 오차: 0.9123
# 987의 평균 절대 오차: 0.8005
# 987의 R-squared: 0.9983
# 988의 평균 제곱 오차: 0.7680
# 988의 평균 절대 오차: 0.7555
# 988의 R-squared: 0.9986
# 989의 평균 제곱 오차: 0.9099
# 989의 평균 절대 오차: 0.7363
# 989의 R-squared: 0.9983
# 990의 평균 제곱 오차: 0.3323
# 990의 평균 절대 오차: 0.5280
# 990의 R-squared: 0.9994
# 991의 평균 제곱 오차: 0.7981
# 991의 평균 절대 오차: 0.8064
# 991의 R-squared: 0.9985
# 992의 평균 제곱 오차: 1.0177
# 992의 평균 절대 오차: 0.8335
# 992의 R-squared: 0.9981
# 993의 평균 제곱 오차: 0.4255
# 993의 평균 절대 오차: 0.5117
# 993의 R-squared: 0.9992
# 994의 평균 제곱 오차: 0.4209
# 994의 평균 절대 오차: 0.5887
# 994의 R-squared: 0.9992
# 995의 평균 제곱 오차: 1.3214
# 995의 평균 절대 오차: 0.9160
# 995의 R-squared: 0.9975
# 996의 평균 제곱 오차: 0.8292
# 996의 평균 절대 오차: 0.7823
# 996의 R-squared: 0.9985
# 997의 평균 제곱 오차: 1.1085
# 997의 평균 절대 오차: 0.6906
# 997의 R-squared: 0.9979
# 998의 평균 제곱 오차: 1.2638
# 998의 평균 절대 오차: 0.8759
# 998의 R-squared: 0.9976
# 999의 평균 제곱 오차: 1.2487
# 999의 평균 절대 오차: 0.7860
# 999의 R-squared: 0.9977
# 1000의 평균 제곱 오차: 0.4148
# 1000의 평균 절대 오차: 0.5553
# 1000의 R-squared: 0.9992
# 1001의 평균 제곱 오차: 0.5644
# 1001의 평균 절대 오차: 0.6037
# 1001의 R-squared: 0.9989
# 1002의 평균 제곱 오차: 0.4076
# 1002의 평균 절대 오차: 0.5211
# 1002의 R-squared: 0.9992
# 1003의 평균 제곱 오차: 0.9517
# 1003의 평균 절대 오차: 0.7721
# 1003의 R-squared: 0.9982
# 1004의 평균 제곱 오차: 0.9918
# 1004의 평균 절대 오차: 0.8010
# 1004의 R-squared: 0.9982
# 1005의 평균 제곱 오차: 0.3901
# 1005의 평균 절대 오차: 0.5128
# 1005의 R-squared: 0.9993
# 1006의 평균 제곱 오차: 0.4425
# 1006의 평균 절대 오차: 0.4983
# 1006의 R-squared: 0.9992
# 1007의 평균 제곱 오차: 0.7401
# 1007의 평균 절대 오차: 0.7511
# 1007의 R-squared: 0.9986
# 1008의 평균 제곱 오차: 0.2814
# 1008의 평균 절대 오차: 0.3813
# 1008의 R-squared: 0.9995
# 1009의 평균 제곱 오차: 0.9701
# 1009의 평균 절대 오차: 0.6818
# 1009의 R-squared: 0.9982
# 1010의 평균 제곱 오차: 0.1744
# 1010의 평균 절대 오차: 0.3996
# 1010의 R-squared: 0.9997
# 1011의 평균 제곱 오차: 0.5774
# 1011의 평균 절대 오차: 0.7204
# 1011의 R-squared: 0.9989
# 1012의 평균 제곱 오차: 0.2468
# 1012의 평균 절대 오차: 0.4460
# 1012의 R-squared: 0.9995
# 1013의 평균 제곱 오차: 0.2498
# 1013의 평균 절대 오차: 0.4581
# 1013의 R-squared: 0.9995
# 1014의 평균 제곱 오차: 0.3884
# 1014의 평균 절대 오차: 0.5201
# 1014의 R-squared: 0.9993
# 1015의 평균 제곱 오차: 0.5705
# 1015의 평균 절대 오차: 0.7273
# 1015의 R-squared: 0.9989
# 1016의 평균 제곱 오차: 0.5547
# 1016의 평균 절대 오차: 0.6296
# 1016의 R-squared: 0.9990
# 1017의 평균 제곱 오차: 0.3961
# 1017의 평균 절대 오차: 0.5745
# 1017의 R-squared: 0.9993
# 1018의 평균 제곱 오차: 0.3162
# 1018의 평균 절대 오차: 0.5315
# 1018의 R-squared: 0.9994
# 1019의 평균 제곱 오차: 0.2789
# 1019의 평균 절대 오차: 0.4003
# 1019의 R-squared: 0.9995
# 1020의 평균 제곱 오차: 0.2529
# 1020의 평균 절대 오차: 0.4203
# 1020의 R-squared: 0.9995
# 1021의 평균 제곱 오차: 0.2650
# 1021의 평균 절대 오차: 0.4531
# 1021의 R-squared: 0.9995
# 1022의 평균 제곱 오차: 0.2343
# 1022의 평균 절대 오차: 0.4346
# 1022의 R-squared: 0.9996
# 1023의 평균 제곱 오차: 0.3616
# 1023의 평균 절대 오차: 0.4965
# 1023의 R-squared: 0.9993
# 1024의 평균 제곱 오차: 0.3667
# 1024의 평균 절대 오차: 0.5619
# 1024의 R-squared: 0.9993
# 1025의 평균 제곱 오차: 0.4028
# 1025의 평균 절대 오차: 0.5830
# 1025의 R-squared: 0.9992
# 1026의 평균 제곱 오차: 0.2586
# 1026의 평균 절대 오차: 0.4712
# 1026의 R-squared: 0.9995
# 1027의 평균 제곱 오차: 0.3730
# 1027의 평균 절대 오차: 0.5298
# 1027의 R-squared: 0.9993
# 1028의 평균 제곱 오차: 0.5141
# 1028의 평균 절대 오차: 0.6316
# 1028의 R-squared: 0.9990
# 1029의 평균 제곱 오차: 0.2017
# 1029의 평균 절대 오차: 0.3701
# 1029의 R-squared: 0.9996
# 1030의 평균 제곱 오차: 1.0234
# 1030의 평균 절대 오차: 0.8237
# 1030의 R-squared: 0.9981
# 1031의 평균 제곱 오차: 0.3645
# 1031의 평균 절대 오차: 0.4334
# 1031의 R-squared: 0.9993
# 1032의 평균 제곱 오차: 0.6180
# 1032의 평균 절대 오차: 0.6266
# 1032의 R-squared: 0.9988
# 1033의 평균 제곱 오차: 0.2607
# 1033의 평균 절대 오차: 0.4434
# 1033의 R-squared: 0.9995
# 1034의 평균 제곱 오차: 0.4879
# 1034의 평균 절대 오차: 0.6559
# 1034의 R-squared: 0.9991
# 1035의 평균 제곱 오차: 0.4258
# 1035의 평균 절대 오차: 0.5846
# 1035의 R-squared: 0.9992
# 1036의 평균 제곱 오차: 0.2707
# 1036의 평균 절대 오차: 0.4583
# 1036의 R-squared: 0.9995
# 1037의 평균 제곱 오차: 0.2404
# 1037의 평균 절대 오차: 0.4362
# 1037의 R-squared: 0.9996
# 1038의 평균 제곱 오차: 0.3595
# 1038의 평균 절대 오차: 0.5020
# 1038의 R-squared: 0.9993
# 1039의 평균 제곱 오차: 0.3990
# 1039의 평균 절대 오차: 0.5265
# 1039의 R-squared: 0.9993
# 1040의 평균 제곱 오차: 0.7066
# 1040의 평균 절대 오차: 0.6171
# 1040의 R-squared: 0.9987
# 1041의 평균 제곱 오차: 0.2918
# 1041의 평균 절대 오차: 0.4993
# 1041의 R-squared: 0.9995
# 1042의 평균 제곱 오차: 0.1924
# 1042의 평균 절대 오차: 0.4229
# 1042의 R-squared: 0.9996
# 1043의 평균 제곱 오차: 0.3043
# 1043의 평균 절대 오차: 0.4839
# 1043의 R-squared: 0.9994
# 1044의 평균 제곱 오차: 0.2957
# 1044의 평균 절대 오차: 0.4420
# 1044의 R-squared: 0.9994
# 1045의 평균 제곱 오차: 0.3426
# 1045의 평균 절대 오차: 0.5088
# 1045의 R-squared: 0.9994
# 1046의 평균 제곱 오차: 0.3699
# 1046의 평균 절대 오차: 0.5334
# 1046의 R-squared: 0.9993
# 1047의 평균 제곱 오차: 0.7177
# 1047의 평균 절대 오차: 0.7354
# 1047의 R-squared: 0.9987
# 1048의 평균 제곱 오차: 0.7665
# 1048의 평균 절대 오차: 0.7641
# 1048의 R-squared: 0.9986
# 1049의 평균 제곱 오차: 0.4599
# 1049의 평균 절대 오차: 0.6337
# 1049의 R-squared: 0.9991
# 1050의 평균 제곱 오차: 0.5160
# 1050의 평균 절대 오차: 0.6231
# 1050의 R-squared: 0.9990
# 1051의 평균 제곱 오차: 0.3564
# 1051의 평균 절대 오차: 0.5124
# 1051의 R-squared: 0.9993
# 1052의 평균 제곱 오차: 0.4520
# 1052의 평균 절대 오차: 0.6078
# 1052의 R-squared: 0.9992
# 1053의 평균 제곱 오차: 0.2411
# 1053의 평균 절대 오차: 0.4638
# 1053의 R-squared: 0.9996
# 1054의 평균 제곱 오차: 0.1817
# 1054의 평균 절대 오차: 0.4047
# 1054의 R-squared: 0.9997
# 1055의 평균 제곱 오차: 0.2576
# 1055의 평균 절대 오차: 0.4917
# 1055의 R-squared: 0.9995
# 1056의 평균 제곱 오차: 0.1897
# 1056의 평균 절대 오차: 0.3954
# 1056의 R-squared: 0.9996
# 1057의 평균 제곱 오차: 0.2796
# 1057의 평균 절대 오차: 0.4697
# 1057의 R-squared: 0.9995
# 1058의 평균 제곱 오차: 0.4374
# 1058의 평균 절대 오차: 0.5943
# 1058의 R-squared: 0.9992
# 1059의 평균 제곱 오차: 0.5611
# 1059의 평균 절대 오차: 0.6778
# 1059의 R-squared: 0.9990
# 1060의 평균 제곱 오차: 0.5504
# 1060의 평균 절대 오차: 0.6747
# 1060의 R-squared: 0.9990
# 1061의 평균 제곱 오차: 0.2831
# 1061의 평균 절대 오차: 0.5124
# 1061의 R-squared: 0.9995
# 1062의 평균 제곱 오차: 0.5775
# 1062의 평균 절대 오차: 0.6560
# 1062의 R-squared: 0.9989
# 1063의 평균 제곱 오차: 0.7134
# 1063의 평균 절대 오차: 0.7008
# 1063의 R-squared: 0.9987
# 1064의 평균 제곱 오차: 0.2869
# 1064의 평균 절대 오차: 0.4993
# 1064의 R-squared: 0.9995
# 1065의 평균 제곱 오차: 0.2223
# 1065의 평균 절대 오차: 0.4197
# 1065의 R-squared: 0.9996
# 1066의 평균 제곱 오차: 0.3620
# 1066의 평균 절대 오차: 0.5150
# 1066의 R-squared: 0.9993
# 1067의 평균 제곱 오차: 0.5341
# 1067의 평균 절대 오차: 0.7124
# 1067의 R-squared: 0.9990
# 1068의 평균 제곱 오차: 0.4952
# 1068의 평균 절대 오차: 0.6170
# 1068의 R-squared: 0.9991
# 1069의 평균 제곱 오차: 0.3203
# 1069의 평균 절대 오차: 0.4729
# 1069의 R-squared: 0.9994
# 1070의 평균 제곱 오차: 0.4211
# 1070의 평균 절대 오차: 0.5982
# 1070의 R-squared: 0.9992
# 1071의 평균 제곱 오차: 0.5126
# 1071의 평균 절대 오차: 0.5994
# 1071의 R-squared: 0.9990
# 1072의 평균 제곱 오차: 0.7405
# 1072의 평균 절대 오차: 0.6265
# 1072의 R-squared: 0.9986
# 1073의 평균 제곱 오차: 0.7785
# 1073의 평균 절대 오차: 0.7315
# 1073의 R-squared: 0.9985
# 1074의 평균 제곱 오차: 0.2607
# 1074의 평균 절대 오차: 0.3959
# 1074의 R-squared: 0.9995
# 1075의 평균 제곱 오차: 0.3699
# 1075의 평균 절대 오차: 0.5489
# 1075의 R-squared: 0.9993
# 1076의 평균 제곱 오차: 0.2655
# 1076의 평균 절대 오차: 0.4086
# 1076의 R-squared: 0.9995
# 1077의 평균 제곱 오차: 0.3099
# 1077의 평균 절대 오차: 0.4978
# 1077의 R-squared: 0.9994
# 1078의 평균 제곱 오차: 0.4721
# 1078의 평균 절대 오차: 0.5922
# 1078의 R-squared: 0.9991
# 1079의 평균 제곱 오차: 0.4594
# 1079의 평균 절대 오차: 0.6186
# 1079의 R-squared: 0.9991
# 1080의 평균 제곱 오차: 0.9102
# 1080의 평균 절대 오차: 0.7377
# 1080의 R-squared: 0.9983
# 1081의 평균 제곱 오차: 0.3303
# 1081의 평균 절대 오차: 0.4635
# 1081의 R-squared: 0.9994
# 1082의 평균 제곱 오차: 0.3559
# 1082의 평균 절대 오차: 0.5045
# 1082의 R-squared: 0.9993
# 1083의 평균 제곱 오차: 0.4283
# 1083의 평균 절대 오차: 0.5559
# 1083의 R-squared: 0.9992
# 1084의 평균 제곱 오차: 0.5075
# 1084의 평균 절대 오차: 0.5613
# 1084의 R-squared: 0.9991
# 1085의 평균 제곱 오차: 1.0123
# 1085의 평균 절대 오차: 0.8305
# 1085의 R-squared: 0.9981
# 1086의 평균 제곱 오차: 1.8643
# 1086의 평균 절대 오차: 1.1309
# 1086의 R-squared: 0.9965
# 1087의 평균 제곱 오차: 1.3733
# 1087의 평균 절대 오차: 0.8661
# 1087의 R-squared: 0.9974
# 1089의 평균 제곱 오차: 0.8396
# 1089의 평균 절대 오차: 0.7101
# 1089의 R-squared: 0.9984
# 1091의 평균 제곱 오차: 0.8707
# 1091의 평균 절대 오차: 0.7897
# 1091의 R-squared: 0.9984
# 1094의 평균 제곱 오차: 0.8699
# 1094의 평균 절대 오차: 0.6869
# 1094의 R-squared: 0.9984
# 1095의 평균 제곱 오차: 0.4173
# 1095의 평균 절대 오차: 0.5454
# 1095의 R-squared: 0.9992
# 1097의 평균 제곱 오차: 0.5384
# 1097의 평균 절대 오차: 0.5828
# 1097의 R-squared: 0.9990
# 1098의 평균 제곱 오차: 0.6038
# 1098의 평균 절대 오차: 0.6696
# 1098의 R-squared: 0.9989
# 1099의 평균 제곱 오차: 0.9212
# 1099의 평균 절대 오차: 0.6896
# 1099의 R-squared: 0.9983
# 1100의 평균 제곱 오차: 0.8216
# 1100의 평균 절대 오차: 0.6615
# 1100의 R-squared: 0.9985
# 1101의 평균 제곱 오차: 0.3115
# 1101의 평균 절대 오차: 0.4620
# 1101의 R-squared: 0.9994
# 1102의 평균 제곱 오차: 0.4893
# 1102의 평균 절대 오차: 0.6330
# 1102의 R-squared: 0.9991
# 1103의 평균 제곱 오차: 0.3491
# 1103의 평균 절대 오차: 0.4813
# 1103의 R-squared: 0.9993
# 1104의 평균 제곱 오차: 1.1438
# 1104의 평균 절대 오차: 0.8417
# 1104의 R-squared: 0.9979
# 1105의 평균 제곱 오차: 0.6827
# 1105의 평균 절대 오차: 0.7378
# 1105의 R-squared: 0.9987
# 1112의 평균 제곱 오차: 0.8639
# 1112의 평균 절대 오차: 0.7323
# 1112의 R-squared: 0.9984
# 1116의 평균 제곱 오차: 1.9021
# 1116의 평균 절대 오차: 0.9590
# 1116의 R-squared: 0.9965
# 1117의 평균 제곱 오차: 0.8752
# 1117의 평균 절대 오차: 0.7036
# 1117의 R-squared: 0.9984
# 1118의 평균 제곱 오차: 0.9626
# 1118의 평균 절대 오차: 0.7717
# 1118의 R-squared: 0.9982
# 1120의 평균 제곱 오차: 0.5473
# 1120의 평균 절대 오차: 0.5984
# 1120의 R-squared: 0.9990
# 1122의 평균 제곱 오차: 0.9185
# 1122의 평균 절대 오차: 0.7791
# 1122의 R-squared: 0.9983
# 1123의 평균 제곱 오차: 0.5366
# 1123의 평균 절대 오차: 0.6821
# 1123의 R-squared: 0.9990
# 1124의 평균 제곱 오차: 1.7049
# 1124의 평균 절대 오차: 0.9499
# 1124의 R-squared: 0.9968
# 1125의 평균 제곱 오차: 0.8263
# 1125의 평균 절대 오차: 0.7500
# 1125의 R-squared: 0.9985
# 1126의 평균 제곱 오차: 1.2616
# 1126의 평균 절대 오차: 0.8097
# 1126의 R-squared: 0.9976
# 1127의 평균 제곱 오차: 2.2471
# 1127의 평균 절대 오차: 1.0485
# 1127의 R-squared: 0.9958
# 1129의 평균 제곱 오차: 0.7704
# 1129의 평균 절대 오차: 0.7417
# 1129의 R-squared: 0.9986
# 1131의 평균 제곱 오차: 1.3335
# 1131의 평균 절대 오차: 1.0014
# 1131의 R-squared: 0.9975
# 1132의 평균 제곱 오차: 0.6825
# 1132의 평균 절대 오차: 0.7205
# 1132의 R-squared: 0.9987
# 1133의 평균 제곱 오차: 1.4600
# 1133의 평균 절대 오차: 0.8178
# 1133의 R-squared: 0.9973
# 1134의 평균 제곱 오차: 1.0066
# 1134의 평균 절대 오차: 0.7379
# 1134의 R-squared: 0.9981
# 1135의 평균 제곱 오차: 0.3445
# 1135의 평균 절대 오차: 0.3996
# 1135의 R-squared: 0.9994
# 1136의 평균 제곱 오차: 0.7476
# 1136의 평균 절대 오차: 0.7454
# 1136의 R-squared: 0.9986
# 1137의 평균 제곱 오차: 0.6515
# 1137의 평균 절대 오차: 0.7673
# 1137의 R-squared: 0.9988
# 1138의 평균 제곱 오차: 0.8012
# 1138의 평균 절대 오차: 0.5888
# 1138의 R-squared: 0.9985
# 1139의 평균 제곱 오차: 1.3072
# 1139의 평균 절대 오차: 0.8861
# 1139의 R-squared: 0.9976
# 1140의 평균 제곱 오차: 1.4113
# 1140의 평균 절대 오차: 0.9338
# 1140의 R-squared: 0.9974
# 1141의 평균 제곱 오차: 0.6008
# 1141의 평균 절대 오차: 0.6015
# 1141의 R-squared: 0.9989
# 1148의 평균 제곱 오차: 0.8611
# 1148의 평균 절대 오차: 0.6978
# 1148의 R-squared: 0.9984
# 1149의 평균 제곱 오차: 1.1812
# 1149의 평균 절대 오차: 0.8279
# 1149의 R-squared: 0.9978
# 1153의 평균 제곱 오차: 0.4540
# 1153의 평균 절대 오차: 0.5628
# 1153의 R-squared: 0.9992
# 1159의 평균 제곱 오차: 0.4715
# 1159의 평균 절대 오차: 0.5773
# 1159의 R-squared: 0.9991
# 1160의 평균 제곱 오차: 0.9757
# 1160의 평균 절대 오차: 0.7899
# 1160의 R-squared: 0.9982
# 1161의 평균 제곱 오차: 0.3170
# 1161의 평균 절대 오차: 0.4636
# 1161의 R-squared: 0.9994
# 1162의 평균 제곱 오차: 0.6082
# 1162의 평균 절대 오차: 0.6727
# 1162의 R-squared: 0.9989
# 1164의 평균 제곱 오차: 1.7851
# 1164의 평균 절대 오차: 1.0452
# 1164의 R-squared: 0.9967
# 1166의 평균 제곱 오차: 0.9196
# 1166의 평균 절대 오차: 0.7579
# 1166의 R-squared: 0.9983
# 1171의 평균 제곱 오차: 0.6332
# 1171의 평균 절대 오차: 0.5982
# 1171의 R-squared: 0.9988
# 1173의 평균 제곱 오차: 0.3902
# 1173의 평균 절대 오차: 0.5011
# 1173의 R-squared: 0.9993
# 1174의 평균 제곱 오차: 0.7399
# 1174의 평균 절대 오차: 0.6532
# 1174의 R-squared: 0.9986
# 1175의 평균 제곱 오차: 0.4793
# 1175의 평균 절대 오차: 0.6213
# 1175의 R-squared: 0.9991
# 1176의 평균 제곱 오차: 0.6177
# 1176의 평균 절대 오차: 0.6288
# 1176의 R-squared: 0.9988
# 1177의 평균 제곱 오차: 0.4079
# 1177의 평균 절대 오차: 0.6183
# 1177의 R-squared: 0.9992
# 1178의 평균 제곱 오차: 0.2494
# 1178의 평균 절대 오차: 0.3079
# 1178의 R-squared: 0.9995
# 1188의 평균 제곱 오차: 0.2319
# 1188의 평균 절대 오차: 0.4029
# 1188의 R-squared: 0.9996
# 1199의 평균 제곱 오차: 0.3701
# 1199의 평균 절대 오차: 0.5166
# 1199의 R-squared: 0.9993
# 1200의 평균 제곱 오차: 0.2363
# 1200의 평균 절대 오차: 0.4303
# 1200의 R-squared: 0.9996

# %%
# 결과 출력
print(f"가장 작은 MSE: {new_min_mse}")
print(f"가장 작은 MAE: {new_min_mae}")
print(f"가장 큰 R-squared: {new_max_r2}")
print(f"가장 작은 MSE에 해당하는 파일 번호: {new_min_file_number}")
# Out:
# 가장 작은 MSE: 0.04259587124337109
# 가장 작은 MAE: 0.17443148525575122
# 가장 큰 R-squared: 0.9999205603375609
# 가장 작은 MSE에 해당하는 파일 번호: 241

# %%
# 비교할 이미지 계산

# %%
test_image_start = 1
test_image_end = 300

# %%
test_image_start = 1
test_image_end = 300

test_k_values = range(test_image_start, test_image_end+1)

# 각 이미지 번호에 대해 처리를 반복합니다.
for test_k in test_k_values:
    image_path = f"test_image/yoon/{test_k}.jpg"

    if os.path.exists(image_path):
        image = cv2.imread(image_path)
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    else:
        print(f"Error: No face detected in the image test_face_{test_k}.")
        continue

    # 이미지에서 얼굴 검출 및 랜드마크 처리
    faces = detector(gray)
    for face in faces:
        landmarks = predictor(gray, face)
        landmarks = np.array([(landmarks.part(n).x, landmarks.part(n).y) for n in range(68)])
                
        # 랜드마크 좌표 간의 유클리드 거리 계산
        distances = pdist(landmarks)
        distance_matrix = squareform(distances)

        # 유클리드 거리를 CSV 파일에 작성
        with open(f"test_landmark_distances/test_landmark_distances({test_k}).csv", "w", newline="") as csvfile2:
            writer2 = csv.writer(csvfile2)
            header = ["Landmark"] + [str(i) for i in range(1, 69)]
            writer2.writerow(header)

            for j in range(68):
                row = [j + 1] + [f"{d:.8f}" for d in distance_matrix[j]]
                writer2.writerow(row)

    print(f"Processing of {test_k} images completed.")
# Out:
# Processing of 1 images completed.
# Processing of 2 images completed.
# Processing of 3 images completed.
# Processing of 4 images completed.
# Processing of 5 images completed.
# Processing of 6 images completed.
# Processing of 7 images completed.
# Processing of 8 images completed.
# Processing of 9 images completed.
# Processing of 10 images completed.
# Processing of 11 images completed.
# Processing of 12 images completed.
# Processing of 13 images completed.
# Processing of 14 images completed.
# Processing of 15 images completed.
# Processing of 16 images completed.
# Processing of 17 images completed.
# Processing of 18 images completed.
# Processing of 19 images completed.
# Processing of 20 images completed.
# Processing of 21 images completed.
# Processing of 22 images completed.
# Processing of 23 images completed.
# Processing of 24 images completed.
# Processing of 25 images completed.
# Processing of 26 images completed.
# Processing of 27 images completed.
# Processing of 28 images completed.
# Processing of 29 images completed.
# Processing of 30 images completed.
# Processing of 31 images completed.
# Processing of 32 images completed.
# Processing of 33 images completed.
# Processing of 34 images completed.
# Processing of 35 images completed.
# Processing of 36 images completed.
# Processing of 37 images completed.
# Processing of 38 images completed.
# Processing of 39 images completed.
# Processing of 40 images completed.
# Processing of 41 images completed.
# Processing of 42 images completed.
# Processing of 43 images completed.
# Processing of 44 images completed.
# Processing of 45 images completed.
# Processing of 46 images completed.
# Processing of 47 images completed.
# Processing of 48 images completed.
# Processing of 49 images completed.
# Processing of 50 images completed.
# Processing of 51 images completed.
# Processing of 52 images completed.
# Processing of 53 images completed.
# Processing of 54 images completed.
# Processing of 55 images completed.
# Processing of 56 images completed.
# Processing of 57 images completed.
# Processing of 58 images completed.
# Processing of 59 images completed.
# Processing of 60 images completed.
# Processing of 61 images completed.
# Processing of 62 images completed.
# Processing of 63 images completed.
# Processing of 64 images completed.
# Processing of 65 images completed.
# Processing of 66 images completed.
# Processing of 67 images completed.
# Processing of 68 images completed.
# Processing of 69 images completed.
# Processing of 70 images completed.
# Processing of 71 images completed.
# Processing of 72 images completed.
# Processing of 73 images completed.
# Processing of 74 images completed.
# Processing of 75 images completed.
# Processing of 76 images completed.
# Processing of 77 images completed.
# Processing of 78 images completed.
# Processing of 79 images completed.
# Processing of 80 images completed.
# Processing of 81 images completed.
# Processing of 82 images completed.
# Processing of 83 images completed.
# Processing of 84 images completed.
# Processing of 85 images completed.
# Processing of 86 images completed.
# Processing of 87 images completed.
# Processing of 88 images completed.
# Processing of 89 images completed.
# Processing of 90 images completed.
# Processing of 91 images completed.
# Processing of 92 images completed.
# Processing of 93 images completed.
# Processing of 94 images completed.
# Processing of 95 images completed.
# Processing of 96 images completed.
# Processing of 97 images completed.
# Processing of 98 images completed.
# Processing of 99 images completed.
# Processing of 100 images completed.
# Processing of 101 images completed.
# Processing of 102 images completed.
# Processing of 103 images completed.
# Processing of 104 images completed.
# Processing of 105 images completed.
# Processing of 106 images completed.
# Processing of 107 images completed.
# Processing of 108 images completed.
# Processing of 109 images completed.
# Processing of 110 images completed.
# Processing of 111 images completed.
# Processing of 112 images completed.
# Processing of 113 images completed.
# Processing of 114 images completed.
# Processing of 115 images completed.
# Processing of 116 images completed.
# Processing of 117 images completed.
# Processing of 118 images completed.
# Processing of 119 images completed.
# Processing of 120 images completed.
# Processing of 121 images completed.
# Processing of 122 images completed.
# Processing of 123 images completed.
# Processing of 124 images completed.
# Processing of 125 images completed.
# Processing of 126 images completed.
# Processing of 127 images completed.
# Processing of 128 images completed.
# Processing of 129 images completed.
# Processing of 130 images completed.
# Processing of 131 images completed.
# Processing of 132 images completed.
# Processing of 133 images completed.
# Processing of 134 images completed.
# Processing of 135 images completed.
# Processing of 136 images completed.
# Processing of 137 images completed.
# Processing of 138 images completed.
# Processing of 139 images completed.
# Processing of 140 images completed.
# Processing of 141 images completed.
# Processing of 142 images completed.
# Processing of 143 images completed.
# Processing of 144 images completed.
# Processing of 145 images completed.
# Processing of 146 images completed.
# Processing of 147 images completed.
# Processing of 148 images completed.
# Processing of 149 images completed.
# Processing of 150 images completed.
# Processing of 151 images completed.
# Processing of 152 images completed.
# Processing of 153 images completed.
# Processing of 154 images completed.
# Processing of 155 images completed.
# Processing of 156 images completed.
# Processing of 157 images completed.
# Processing of 158 images completed.
# Processing of 159 images completed.
# Processing of 160 images completed.
# Processing of 161 images completed.
# Processing of 162 images completed.
# Processing of 163 images completed.
# Processing of 164 images completed.
# Processing of 165 images completed.
# Processing of 166 images completed.
# Processing of 167 images completed.
# Processing of 168 images completed.
# Processing of 169 images completed.
# Processing of 170 images completed.
# Processing of 171 images completed.
# Processing of 172 images completed.
# Processing of 173 images completed.
# Processing of 174 images completed.
# Processing of 175 images completed.
# Processing of 176 images completed.
# Processing of 177 images completed.
# Processing of 178 images completed.
# Processing of 179 images completed.
# Processing of 180 images completed.
# Processing of 181 images completed.
# Processing of 182 images completed.
# Processing of 183 images completed.
# Processing of 184 images completed.
# Processing of 185 images completed.
# Processing of 186 images completed.
# Processing of 187 images completed.
# Processing of 188 images completed.
# Processing of 189 images completed.
# Processing of 190 images completed.
# Processing of 191 images completed.
# Processing of 192 images completed.
# Processing of 193 images completed.
# Processing of 194 images completed.
# Processing of 195 images completed.
# Processing of 196 images completed.
# Processing of 197 images completed.
# Processing of 198 images completed.
# Processing of 199 images completed.
# Processing of 200 images completed.
# Processing of 201 images completed.
# Processing of 202 images completed.
# Processing of 203 images completed.
# Processing of 204 images completed.
# Processing of 205 images completed.
# Processing of 206 images completed.
# Processing of 207 images completed.
# Processing of 208 images completed.
# Processing of 209 images completed.
# Processing of 210 images completed.
# Processing of 211 images completed.
# Processing of 212 images completed.
# Processing of 213 images completed.
# Processing of 214 images completed.
# Processing of 215 images completed.
# Processing of 216 images completed.
# Processing of 217 images completed.
# Processing of 218 images completed.
# Processing of 219 images completed.
# Processing of 220 images completed.
# Processing of 221 images completed.
# Processing of 222 images completed.
# Processing of 223 images completed.
# Processing of 224 images completed.
# Processing of 225 images completed.
# Processing of 226 images completed.
# Processing of 227 images completed.
# Processing of 228 images completed.
# Processing of 229 images completed.
# Processing of 230 images completed.
# Processing of 231 images completed.
# Processing of 232 images completed.
# Processing of 233 images completed.
# Processing of 234 images completed.
# Processing of 235 images completed.
# Processing of 236 images completed.
# Processing of 237 images completed.
# Processing of 238 images completed.
# Processing of 239 images completed.
# Processing of 240 images completed.
# Processing of 241 images completed.
# Processing of 242 images completed.
# Processing of 243 images completed.
# Processing of 244 images completed.
# Processing of 245 images completed.
# Processing of 246 images completed.
# Processing of 247 images completed.
# Processing of 248 images completed.
# Processing of 249 images completed.
# Processing of 250 images completed.
# Processing of 251 images completed.
# Processing of 252 images completed.
# Processing of 253 images completed.
# Processing of 254 images completed.
# Processing of 255 images completed.
# Processing of 256 images completed.
# Processing of 257 images completed.
# Processing of 258 images completed.
# Processing of 259 images completed.
# Processing of 260 images completed.
# Processing of 261 images completed.
# Processing of 262 images completed.
# Processing of 263 images completed.
# Processing of 264 images completed.
# Processing of 265 images completed.
# Processing of 266 images completed.
# Processing of 267 images completed.
# Processing of 268 images completed.
# Processing of 269 images completed.
# Processing of 270 images completed.
# Processing of 271 images completed.
# Processing of 272 images completed.
# Processing of 273 images completed.
# Processing of 274 images completed.
# Processing of 275 images completed.
# Processing of 276 images completed.
# Processing of 277 images completed.
# Processing of 278 images completed.
# Processing of 279 images completed.
# Processing of 280 images completed.
# Processing of 281 images completed.
# Processing of 282 images completed.
# Processing of 283 images completed.
# Processing of 284 images completed.
# Processing of 285 images completed.
# Processing of 286 images completed.
# Processing of 287 images completed.
# Processing of 288 images completed.
# Processing of 289 images completed.
# Processing of 290 images completed.
# Processing of 291 images completed.
# Processing of 292 images completed.
# Processing of 293 images completed.
# Processing of 294 images completed.
# Processing of 295 images completed.
# Processing of 296 images completed.
# Processing of 297 images completed.
# Processing of 298 images completed.
# Processing of 299 images completed.
# Processing of 300 images completed.

# %%
# test할 이미지의 데이터를 가져와 훈련시키고 나온 mse값을 가지고 비교하여 사진 판별

test_min_mse = float("inf")
test_min_mae = float("inf")
test_max_r2 = float(0)
test_min_file_number = None

file_numbers = range(test_image_start, test_image_end+1)  # 1부터 300까지의 파일 번호 리스트

# 각 파일 번호에 대해 처리를 반복합니다.
for file_number in file_numbers:
    test_distances_file = f"test_landmark_distances/test_landmark_distances({file_number}).csv"

    # 파일이 존재하는지 확인
    if not os.path.exists(test_distances_file):
        continue

    # 새로운 landmark 좌표와 거리를 CSV 파일로부터 로드
    test_data = pd.read_csv(test_distances_file)

    X_new = test_data.drop(columns=["Landmark"])
    Y_new = test_data["Landmark"]

    # 데이터를 훈련 세트와 테스트 세트로 분할
    X_train, X_test, y_train, y_test = train_test_split(X_new, Y_new, test_size=0.1, random_state=min_i)

    # 선형 회귀 모델 생성 및 훈련
    model = LinearRegression()
    model.fit(X_train, y_train)

    # 테스트 세트에서 예측 수행
    test_predictions = model.predict(X_test)

    # R-squared 계산
    test_r2 = r2_score(y_test, test_predictions)
    
    # 평균 제곱 오차(MSE) 계산
    test_mse = mean_squared_error(y_test, test_predictions)
    
    # 평균 절대 오차(MAE) 계산
    test_mae = mean_absolute_error(y_test, test_predictions)
    
    # 각 파일에 대한 MSE를 찾아 가장 작은 MSE를 찾고 파일 번호를 업데이트합니다.
    if test_mse < test_min_mse and test_mae < test_min_mae and test_r2 > test_max_r2:
        test_min_mse = test_mse
        test_min_mae = test_mae
        test_max_r2 = test_r2    
        test_min_file_number = file_number

    # 각 파일에 대한 평균 제곱 오차 출력    
    print(f"{file_number}의 평균 제곱 오차: {test_mse:.4f}")
    print(f"{file_number}의 평균 절대 오차: {test_mae:.4f}")
    print(f"{file_number}의 R-squared: {test_r2:.4f}")
# Out:
# 1의 평균 제곱 오차: 2.1324
# 1의 평균 절대 오차: 1.0712
# 1의 R-squared: 0.9960
# 2의 평균 제곱 오차: 1.9398
# 2의 평균 절대 오차: 0.8786
# 2의 R-squared: 0.9964
# 3의 평균 제곱 오차: 1.9502
# 3의 평균 절대 오차: 0.9290
# 3의 R-squared: 0.9964
# 4의 평균 제곱 오차: 2.8139
# 4의 평균 절대 오차: 1.0705
# 4의 R-squared: 0.9948
# 5의 평균 제곱 오차: 2.6675
# 5의 평균 절대 오차: 0.9076
# 5의 R-squared: 0.9950
# 6의 평균 제곱 오차: 1.6764
# 6의 평균 절대 오차: 0.9433
# 6의 R-squared: 0.9969
# 7의 평균 제곱 오차: 1.5256
# 7의 평균 절대 오차: 0.8730
# 7의 R-squared: 0.9972
# 8의 평균 제곱 오차: 1.1786
# 8의 평균 절대 오차: 0.8060
# 8의 R-squared: 0.9978
# 9의 평균 제곱 오차: 1.7487
# 9의 평균 절대 오차: 0.8614
# 9의 R-squared: 0.9967
# 10의 평균 제곱 오차: 3.5893
# 10의 평균 절대 오차: 1.0898
# 10의 R-squared: 0.9933
# 11의 평균 제곱 오차: 2.7565
# 11의 평균 절대 오차: 1.0571
# 11의 R-squared: 0.9949
# 12의 평균 제곱 오차: 1.8557
# 12의 평균 절대 오차: 0.8928
# 12의 R-squared: 0.9965
# 13의 평균 제곱 오차: 1.8222
# 13의 평균 절대 오차: 0.8616
# 13의 R-squared: 0.9966
# 14의 평균 제곱 오차: 1.9435
# 14의 평균 절대 오차: 1.0076
# 14의 R-squared: 0.9964
# 15의 평균 제곱 오차: 2.6185
# 15의 평균 절대 오차: 0.9588
# 15의 R-squared: 0.9951
# 16의 평균 제곱 오차: 1.8560
# 16의 평균 절대 오차: 0.9416
# 16의 R-squared: 0.9965
# 17의 평균 제곱 오차: 2.1039
# 17의 평균 절대 오차: 1.0692
# 17의 R-squared: 0.9961
# 18의 평균 제곱 오차: 2.0590
# 18의 평균 절대 오차: 1.0541
# 18의 R-squared: 0.9962
# 19의 평균 제곱 오차: 1.7934
# 19의 평균 절대 오차: 0.8973
# 19의 R-squared: 0.9967
# 20의 평균 제곱 오차: 1.9284
# 20의 평균 절대 오차: 0.9313
# 20의 R-squared: 0.9964
# 21의 평균 제곱 오차: 1.7027
# 21의 평균 절대 오차: 0.7754
# 21의 R-squared: 0.9968
# 22의 평균 제곱 오차: 1.8928
# 22의 평균 절대 오차: 0.8722
# 22의 R-squared: 0.9965
# 23의 평균 제곱 오차: 1.3359
# 23의 평균 절대 오차: 0.8800
# 23의 R-squared: 0.9975
# 24의 평균 제곱 오차: 2.5765
# 24의 평균 절대 오차: 1.0392
# 24의 R-squared: 0.9952
# 25의 평균 제곱 오차: 2.8901
# 25의 평균 절대 오차: 1.0388
# 25의 R-squared: 0.9946
# 26의 평균 제곱 오차: 2.6806
# 26의 평균 절대 오차: 1.0929
# 26의 R-squared: 0.9950
# 27의 평균 제곱 오차: 2.7786
# 27의 평균 절대 오차: 1.0695
# 27의 R-squared: 0.9948
# 28의 평균 제곱 오차: 1.2948
# 28의 평균 절대 오차: 0.7578
# 28의 R-squared: 0.9976
# 29의 평균 제곱 오차: 2.0153
# 29의 평균 절대 오차: 0.8757
# 29의 R-squared: 0.9962
# 30의 평균 제곱 오차: 2.1354
# 30의 평균 절대 오차: 0.9943
# 30의 R-squared: 0.9960
# 31의 평균 제곱 오차: 2.2313
# 31의 평균 절대 오차: 0.9915
# 31의 R-squared: 0.9958
# 32의 평균 제곱 오차: 1.7303
# 32의 평균 절대 오차: 0.8651
# 32의 R-squared: 0.9968
# 33의 평균 제곱 오차: 1.2946
# 33의 평균 절대 오차: 0.7843
# 33의 R-squared: 0.9976
# 34의 평균 제곱 오차: 1.5113
# 34의 평균 절대 오차: 0.9344
# 34의 R-squared: 0.9972
# 35의 평균 제곱 오차: 1.9932
# 35의 평균 절대 오차: 1.0229
# 35의 R-squared: 0.9963
# 36의 평균 제곱 오차: 1.4772
# 36의 평균 절대 오차: 0.8287
# 36의 R-squared: 0.9972
# 37의 평균 제곱 오차: 1.6424
# 37의 평균 절대 오차: 0.7811
# 37의 R-squared: 0.9969
# 38의 평균 제곱 오차: 2.0717
# 38의 평균 절대 오차: 0.9989
# 38의 R-squared: 0.9961
# 39의 평균 제곱 오차: 2.0612
# 39의 평균 절대 오차: 0.9887
# 39의 R-squared: 0.9962
# 40의 평균 제곱 오차: 1.8791
# 40의 평균 절대 오차: 0.9631
# 40의 R-squared: 0.9965
# 41의 평균 제곱 오차: 1.9291
# 41의 평균 절대 오차: 0.8506
# 41의 R-squared: 0.9964
# 42의 평균 제곱 오차: 1.6328
# 42의 평균 절대 오차: 0.8216
# 42의 R-squared: 0.9970
# 43의 평균 제곱 오차: 1.9652
# 43의 평균 절대 오차: 0.9320
# 43의 R-squared: 0.9963
# 44의 평균 제곱 오차: 1.1002
# 44의 평균 절대 오차: 0.7109
# 44의 R-squared: 0.9979
# 45의 평균 제곱 오차: 2.0470
# 45의 평균 절대 오차: 0.9321
# 45의 R-squared: 0.9962
# 46의 평균 제곱 오차: 1.7657
# 46의 평균 절대 오차: 0.8929
# 46의 R-squared: 0.9967
# 47의 평균 제곱 오차: 2.1748
# 47의 평균 절대 오차: 1.0612
# 47의 R-squared: 0.9959
# 48의 평균 제곱 오차: 1.9915
# 48의 평균 절대 오차: 1.0029
# 48의 R-squared: 0.9963
# 49의 평균 제곱 오차: 1.7258
# 49의 평균 절대 오차: 0.9203
# 49의 R-squared: 0.9968
# 50의 평균 제곱 오차: 2.3218
# 50의 평균 절대 오차: 1.2156
# 50의 R-squared: 0.9957
# 51의 평균 제곱 오차: 2.1089
# 51의 평균 절대 오차: 0.9011
# 51의 R-squared: 0.9961
# 52의 평균 제곱 오차: 2.5548
# 52의 평균 절대 오차: 0.9612
# 52의 R-squared: 0.9952
# 53의 평균 제곱 오차: 1.7090
# 53의 평균 절대 오차: 0.8972
# 53의 R-squared: 0.9968
# 54의 평균 제곱 오차: 1.8235
# 54의 평균 절대 오차: 0.8651
# 54의 R-squared: 0.9966
# 55의 평균 제곱 오차: 1.9074
# 55의 평균 절대 오차: 0.9684
# 55의 R-squared: 0.9964
# 56의 평균 제곱 오차: 2.9884
# 56의 평균 절대 오차: 1.0128
# 56의 R-squared: 0.9944
# 57의 평균 제곱 오차: 1.6450
# 57의 평균 절대 오차: 0.8311
# 57의 R-squared: 0.9969
# 58의 평균 제곱 오차: 2.8468
# 58의 평균 절대 오차: 1.1017
# 58의 R-squared: 0.9947
# 59의 평균 제곱 오차: 2.8344
# 59의 평균 절대 오차: 1.0195
# 59의 R-squared: 0.9947
# 60의 평균 제곱 오차: 2.9472
# 60의 평균 절대 오차: 1.1230
# 60의 R-squared: 0.9945
# 61의 평균 제곱 오차: 2.7967
# 61의 평균 절대 오차: 1.1284
# 61의 R-squared: 0.9948
# 62의 평균 제곱 오차: 1.4100
# 62의 평균 절대 오차: 0.8566
# 62의 R-squared: 0.9974
# 63의 평균 제곱 오차: 2.8059
# 63의 평균 절대 오차: 1.1151
# 63의 R-squared: 0.9948
# 64의 평균 제곱 오차: 2.8950
# 64의 평균 절대 오차: 1.0991
# 64의 R-squared: 0.9946
# 65의 평균 제곱 오차: 1.7153
# 65의 평균 절대 오차: 0.8734
# 65의 R-squared: 0.9968
# 66의 평균 제곱 오차: 3.2614
# 66의 평균 절대 오차: 1.2067
# 66의 R-squared: 0.9939
# 67의 평균 제곱 오차: 2.6351
# 67의 평균 절대 오차: 0.9638
# 67의 R-squared: 0.9951
# 68의 평균 제곱 오차: 2.7309
# 68의 평균 절대 오차: 1.0749
# 68의 R-squared: 0.9949
# 69의 평균 제곱 오차: 2.0060
# 69의 평균 절대 오차: 0.8547
# 69의 R-squared: 0.9963
# 70의 평균 제곱 오차: 3.0859
# 70의 평균 절대 오차: 1.0888
# 70의 R-squared: 0.9942
# 71의 평균 제곱 오차: 4.1433
# 71의 평균 절대 오차: 1.1620
# 71의 R-squared: 0.9923
# 72의 평균 제곱 오차: 3.9824
# 72의 평균 절대 오차: 1.2235
# 72의 R-squared: 0.9926
# 73의 평균 제곱 오차: 2.8196
# 73의 평균 절대 오차: 0.9882
# 73의 R-squared: 0.9947
# 74의 평균 제곱 오차: 2.7824
# 74의 평균 절대 오차: 0.9181
# 74의 R-squared: 0.9948
# 75의 평균 제곱 오차: 2.0082
# 75의 평균 절대 오차: 0.9315
# 75의 R-squared: 0.9963
# 76의 평균 제곱 오차: 2.0318
# 76의 평균 절대 오차: 0.9588
# 76의 R-squared: 0.9962
# 77의 평균 제곱 오차: 4.0746
# 77의 평균 절대 오차: 1.2996
# 77의 R-squared: 0.9924
# 78의 평균 제곱 오차: 3.1538
# 78의 평균 절대 오차: 1.0162
# 78의 R-squared: 0.9941
# 79의 평균 제곱 오차: 2.1036
# 79의 평균 절대 오차: 0.9564
# 79의 R-squared: 0.9961
# 80의 평균 제곱 오차: 3.5808
# 80의 평균 절대 오차: 1.0784
# 80의 R-squared: 0.9933
# 81의 평균 제곱 오차: 3.8479
# 81의 평균 절대 오차: 1.1030
# 81의 R-squared: 0.9928
# 82의 평균 제곱 오차: 1.7481
# 82의 평균 절대 오차: 0.8421
# 82의 R-squared: 0.9967
# 83의 평균 제곱 오차: 2.2123
# 83의 평균 절대 오차: 0.9669
# 83의 R-squared: 0.9959
# 84의 평균 제곱 오차: 2.6366
# 84의 평균 절대 오차: 0.9845
# 84의 R-squared: 0.9951
# 85의 평균 제곱 오차: 4.0575
# 85의 평균 절대 오차: 1.2943
# 85의 R-squared: 0.9924
# 86의 평균 제곱 오차: 2.0627
# 86의 평균 절대 오차: 0.9915
# 86의 R-squared: 0.9962
# 87의 평균 제곱 오차: 2.8795
# 87의 평균 절대 오차: 1.0435
# 87의 R-squared: 0.9946
# 88의 평균 제곱 오차: 3.7746
# 88의 평균 절대 오차: 1.2225
# 88의 R-squared: 0.9930
# 89의 평균 제곱 오차: 3.0524
# 89의 평균 절대 오차: 1.2014
# 89의 R-squared: 0.9943
# 90의 평균 제곱 오차: 4.0157
# 90의 평균 절대 오차: 1.1087
# 90의 R-squared: 0.9925
# 91의 평균 제곱 오차: 1.4855
# 91의 평균 절대 오차: 0.8847
# 91의 R-squared: 0.9972
# 92의 평균 제곱 오차: 2.7724
# 92의 평균 절대 오차: 0.9622
# 92의 R-squared: 0.9948
# 93의 평균 제곱 오차: 3.2906
# 93의 평균 절대 오차: 1.0589
# 93의 R-squared: 0.9939
# 94의 평균 제곱 오차: 2.4104
# 94의 평균 절대 오차: 1.1709
# 94의 R-squared: 0.9955
# 95의 평균 제곱 오차: 3.8885
# 95의 평균 절대 오차: 1.0445
# 95의 R-squared: 0.9927
# 96의 평균 제곱 오차: 3.2255
# 96의 평균 절대 오차: 1.2700
# 96의 R-squared: 0.9940
# 97의 평균 제곱 오차: 4.2034
# 97의 평균 절대 오차: 1.1794
# 97의 R-squared: 0.9922
# 98의 평균 제곱 오차: 1.8658
# 98의 평균 절대 오차: 0.8514
# 98의 R-squared: 0.9965
# 99의 평균 제곱 오차: 2.9570
# 99의 평균 절대 오차: 1.0455
# 99의 R-squared: 0.9945
# 100의 평균 제곱 오차: 2.7304
# 100의 평균 절대 오차: 1.1041
# 100의 R-squared: 0.9949
# 101의 평균 제곱 오차: 3.9327
# 101의 평균 절대 오차: 1.1732
# 101의 R-squared: 0.9927
# 102의 평균 제곱 오차: 3.9772
# 102의 평균 절대 오차: 1.1433
# 102의 R-squared: 0.9926
# 103의 평균 제곱 오차: 4.0443
# 103의 평균 절대 오차: 1.1766
# 103의 R-squared: 0.9925
# 104의 평균 제곱 오차: 4.0898
# 104의 평균 절대 오차: 1.1922
# 104의 R-squared: 0.9924
# 105의 평균 제곱 오차: 3.9508
# 105의 평균 절대 오차: 1.2408
# 105의 R-squared: 0.9926
# 106의 평균 제곱 오차: 3.2260
# 106의 평균 절대 오차: 1.1649
# 106의 R-squared: 0.9940
# 107의 평균 제곱 오차: 1.9258
# 107의 평균 절대 오차: 0.9998
# 107의 R-squared: 0.9964
# 108의 평균 제곱 오차: 5.1035
# 108의 평균 절대 오차: 1.2250
# 108의 R-squared: 0.9905
# 109의 평균 제곱 오차: 3.5766
# 109의 평균 절대 오차: 1.0379
# 109의 R-squared: 0.9933
# 110의 평균 제곱 오차: 3.4311
# 110의 평균 절대 오차: 1.2646
# 110의 R-squared: 0.9936
# 111의 평균 제곱 오차: 3.1837
# 111의 평균 절대 오차: 1.2555
# 111의 R-squared: 0.9941
# 112의 평균 제곱 오차: 2.6161
# 112의 평균 절대 오차: 0.9703
# 112의 R-squared: 0.9951
# 113의 평균 제곱 오차: 4.3274
# 113의 평균 절대 오차: 1.4049
# 113의 R-squared: 0.9919
# 114의 평균 제곱 오차: 2.9623
# 114의 평균 절대 오차: 1.1688
# 114의 R-squared: 0.9945
# 115의 평균 제곱 오차: 3.1521
# 115의 평균 절대 오차: 1.1154
# 115의 R-squared: 0.9941
# 116의 평균 제곱 오차: 3.1935
# 116의 평균 절대 오차: 1.0505
# 116의 R-squared: 0.9940
# 117의 평균 제곱 오차: 2.7655
# 117의 평균 절대 오차: 1.0384
# 117의 R-squared: 0.9948
# 118의 평균 제곱 오차: 2.8605
# 118의 평균 절대 오차: 1.0195
# 118의 R-squared: 0.9947
# 119의 평균 제곱 오차: 3.3768
# 119의 평균 절대 오차: 0.9997
# 119의 R-squared: 0.9937
# 120의 평균 제곱 오차: 3.4787
# 120의 평균 절대 오차: 1.2500
# 120의 R-squared: 0.9935
# 121의 평균 제곱 오차: 4.1089
# 121의 평균 절대 오차: 1.3168
# 121의 R-squared: 0.9923
# 122의 평균 제곱 오차: 3.1818
# 122의 평균 절대 오차: 1.1079
# 122의 R-squared: 0.9941
# 123의 평균 제곱 오차: 3.4201
# 123의 평균 절대 오차: 1.2191
# 123의 R-squared: 0.9936
# 124의 평균 제곱 오차: 4.0453
# 124의 평균 절대 오차: 1.1753
# 124의 R-squared: 0.9925
# 125의 평균 제곱 오차: 2.9487
# 125의 평균 절대 오차: 1.0322
# 125의 R-squared: 0.9945
# 126의 평균 제곱 오차: 3.1949
# 126의 평균 절대 오차: 1.1949
# 126의 R-squared: 0.9940
# 127의 평균 제곱 오차: 3.2436
# 127의 평균 절대 오차: 1.1561
# 127의 R-squared: 0.9940
# 128의 평균 제곱 오차: 2.3696
# 128의 평균 절대 오차: 1.0487
# 128의 R-squared: 0.9956
# 129의 평균 제곱 오차: 1.7414
# 129의 평균 절대 오차: 0.9220
# 129의 R-squared: 0.9968
# 130의 평균 제곱 오차: 1.8598
# 130의 평균 절대 오차: 0.9180
# 130의 R-squared: 0.9965
# 131의 평균 제곱 오차: 2.9018
# 131의 평균 절대 오차: 1.0803
# 131의 R-squared: 0.9946
# 132의 평균 제곱 오차: 2.2477
# 132의 평균 절대 오차: 1.0437
# 132의 R-squared: 0.9958
# 133의 평균 제곱 오차: 3.2398
# 133의 평균 절대 오차: 1.0742
# 133의 R-squared: 0.9940
# 134의 평균 제곱 오차: 3.3392
# 134의 평균 절대 오차: 1.2391
# 134의 R-squared: 0.9938
# 135의 평균 제곱 오차: 3.0164
# 135의 평균 절대 오차: 1.0502
# 135의 R-squared: 0.9944
# 136의 평균 제곱 오차: 1.8261
# 136의 평균 절대 오차: 0.8410
# 136의 R-squared: 0.9966
# 137의 평균 제곱 오차: 2.2352
# 137의 평균 절대 오차: 1.0332
# 137의 R-squared: 0.9958
# 138의 평균 제곱 오차: 3.0742
# 138의 평균 절대 오차: 1.1009
# 138의 R-squared: 0.9943
# 139의 평균 제곱 오차: 1.9111
# 139의 평균 절대 오차: 0.8724
# 139의 R-squared: 0.9964
# 140의 평균 제곱 오차: 4.2867
# 140의 평균 절대 오차: 1.2065
# 140의 R-squared: 0.9920
# 141의 평균 제곱 오차: 4.2564
# 141의 평균 절대 오차: 1.2359
# 141의 R-squared: 0.9921
# 142의 평균 제곱 오차: 2.1350
# 142의 평균 절대 오차: 0.9679
# 142의 R-squared: 0.9960
# 143의 평균 제곱 오차: 3.8068
# 143의 평균 절대 오차: 1.2363
# 143의 R-squared: 0.9929
# 144의 평균 제곱 오차: 1.7401
# 144의 평균 절대 오차: 0.8474
# 144의 R-squared: 0.9968
# 145의 평균 제곱 오차: 1.4508
# 145의 평균 절대 오차: 0.9670
# 145의 R-squared: 0.9973
# 146의 평균 제곱 오차: 1.7510
# 146의 평균 절대 오차: 0.9019
# 146의 R-squared: 0.9967
# 147의 평균 제곱 오차: 3.7658
# 147의 평균 절대 오차: 1.1041
# 147의 R-squared: 0.9930
# 148의 평균 제곱 오차: 2.9678
# 148의 평균 절대 오차: 1.1489
# 148의 R-squared: 0.9945
# 149의 평균 제곱 오차: 3.0472
# 149의 평균 절대 오차: 1.1827
# 149의 R-squared: 0.9943
# 150의 평균 제곱 오차: 1.8668
# 150의 평균 절대 오차: 0.9314
# 150의 R-squared: 0.9965
# 151의 평균 제곱 오차: 2.7695
# 151의 평균 절대 오차: 1.0808
# 151의 R-squared: 0.9948
# 152의 평균 제곱 오차: 1.9999
# 152의 평균 절대 오차: 0.8908
# 152의 R-squared: 0.9963
# 153의 평균 제곱 오차: 3.0900
# 153의 평균 절대 오차: 1.1600
# 153의 R-squared: 0.9942
# 154의 평균 제곱 오차: 1.2000
# 154의 평균 절대 오차: 0.8455
# 154의 R-squared: 0.9978
# 155의 평균 제곱 오차: 2.3318
# 155의 평균 절대 오차: 1.1307
# 155의 R-squared: 0.9957
# 156의 평균 제곱 오차: 2.8236
# 156의 평균 절대 오차: 1.0296
# 156의 R-squared: 0.9947
# 157의 평균 제곱 오차: 3.0942
# 157의 평균 절대 오차: 1.0089
# 157의 R-squared: 0.9942
# 158의 평균 제곱 오차: 3.7651
# 158의 평균 절대 오차: 1.1209
# 158의 R-squared: 0.9930
# 159의 평균 제곱 오차: 1.8816
# 159의 평균 절대 오차: 0.9046
# 159의 R-squared: 0.9965
# 160의 평균 제곱 오차: 1.0464
# 160의 평균 절대 오차: 0.7782
# 160의 R-squared: 0.9980
# 161의 평균 제곱 오차: 1.8835
# 161의 평균 절대 오차: 0.8894
# 161의 R-squared: 0.9965
# 162의 평균 제곱 오차: 2.7780
# 162의 평균 절대 오차: 1.0810
# 162의 R-squared: 0.9948
# 163의 평균 제곱 오차: 3.0070
# 163의 평균 절대 오차: 1.0783
# 163의 R-squared: 0.9944
# 164의 평균 제곱 오차: 1.0713
# 164의 평균 절대 오차: 0.7592
# 164의 R-squared: 0.9980
# 165의 평균 제곱 오차: 3.0418
# 165의 평균 절대 오차: 1.0202
# 165의 R-squared: 0.9943
# 166의 평균 제곱 오차: 1.8741
# 166의 평균 절대 오차: 0.8652
# 166의 R-squared: 0.9965
# 167의 평균 제곱 오차: 1.8738
# 167의 평균 절대 오차: 0.8398
# 167의 R-squared: 0.9965
# 168의 평균 제곱 오차: 3.1628
# 168의 평균 절대 오차: 1.1325
# 168의 R-squared: 0.9941
# 169의 평균 제곱 오차: 2.7681
# 169의 평균 절대 오차: 1.1266
# 169의 R-squared: 0.9948
# 170의 평균 제곱 오차: 1.8874
# 170의 평균 절대 오차: 0.9482
# 170의 R-squared: 0.9965
# 171의 평균 제곱 오차: 2.6673
# 171의 평균 절대 오차: 0.9328
# 171의 R-squared: 0.9950
# 172의 평균 제곱 오차: 2.7547
# 172의 평균 절대 오차: 0.9924
# 172의 R-squared: 0.9949
# 173의 평균 제곱 오차: 3.3861
# 173의 평균 절대 오차: 1.1436
# 173의 R-squared: 0.9937
# 174의 평균 제곱 오차: 2.0079
# 174의 평균 절대 오차: 0.9552
# 174의 R-squared: 0.9963
# 175의 평균 제곱 오차: 3.2293
# 175의 평균 절대 오차: 1.1401
# 175의 R-squared: 0.9940
# 176의 평균 제곱 오차: 3.0333
# 176의 평균 절대 오차: 1.1675
# 176의 R-squared: 0.9943
# 177의 평균 제곱 오차: 1.9881
# 177의 평균 절대 오차: 1.0815
# 177의 R-squared: 0.9963
# 178의 평균 제곱 오차: 3.1109
# 178의 평균 절대 오차: 1.0747
# 178의 R-squared: 0.9942
# 179의 평균 제곱 오차: 2.1621
# 179의 평균 절대 오차: 1.0310
# 179의 R-squared: 0.9960
# 180의 평균 제곱 오차: 2.0232
# 180의 평균 절대 오차: 0.9753
# 180의 R-squared: 0.9962
# 181의 평균 제곱 오차: 2.9027
# 181의 평균 절대 오차: 1.1309
# 181의 R-squared: 0.9946
# 182의 평균 제곱 오차: 2.1274
# 182의 평균 절대 오차: 0.9693
# 182의 R-squared: 0.9960
# 183의 평균 제곱 오차: 2.9883
# 183의 평균 절대 오차: 1.1533
# 183의 R-squared: 0.9944
# 184의 평균 제곱 오차: 2.8933
# 184의 평균 절대 오차: 1.0803
# 184의 R-squared: 0.9946
# 185의 평균 제곱 오차: 2.7613
# 185의 평균 절대 오차: 1.0316
# 185의 R-squared: 0.9949
# 186의 평균 제곱 오차: 3.6199
# 186의 평균 절대 오차: 1.1103
# 186의 R-squared: 0.9932
# 187의 평균 제곱 오차: 1.1170
# 187의 평균 절대 오차: 0.8603
# 187의 R-squared: 0.9979
# 188의 평균 제곱 오차: 1.2548
# 188의 평균 절대 오차: 0.8122
# 188의 R-squared: 0.9977
# 189의 평균 제곱 오차: 1.0933
# 189의 평균 절대 오차: 0.7219
# 189의 R-squared: 0.9980
# 190의 평균 제곱 오차: 1.1389
# 190의 평균 절대 오차: 0.8161
# 190의 R-squared: 0.9979
# 191의 평균 제곱 오차: 1.2916
# 191의 평균 절대 오차: 0.8864
# 191의 R-squared: 0.9976
# 192의 평균 제곱 오차: 0.5206
# 192의 평균 절대 오차: 0.5634
# 192의 R-squared: 0.9990
# 193의 평균 제곱 오차: 1.1208
# 193의 평균 절대 오차: 0.6998
# 193의 R-squared: 0.9979
# 194의 평균 제곱 오차: 1.8406
# 194의 평균 절대 오차: 0.9148
# 194의 R-squared: 0.9966
# 195의 평균 제곱 오차: 1.1171
# 195의 평균 절대 오차: 0.7819
# 195의 R-squared: 0.9979
# 196의 평균 제곱 오차: 2.9270
# 196의 평균 절대 오차: 1.2041
# 196의 R-squared: 0.9945
# 197의 평균 제곱 오차: 1.2510
# 197의 평균 절대 오차: 0.7980
# 197의 R-squared: 0.9977
# 198의 평균 제곱 오차: 2.7858
# 198의 평균 절대 오차: 0.9433
# 198의 R-squared: 0.9948
# 199의 평균 제곱 오차: 4.0873
# 199의 평균 절대 오차: 1.2349
# 199의 R-squared: 0.9924
# 200의 평균 제곱 오차: 1.9775
# 200의 평균 절대 오차: 0.9191
# 200의 R-squared: 0.9963
# 201의 평균 제곱 오차: 2.6904
# 201의 평균 절대 오차: 0.9769
# 201의 R-squared: 0.9950
# 202의 평균 제곱 오차: 4.6671
# 202의 평균 절대 오차: 1.1854
# 202의 R-squared: 0.9913
# 203의 평균 제곱 오차: 2.8004
# 203의 평균 절대 오차: 0.9506
# 203의 R-squared: 0.9948
# 204의 평균 제곱 오차: 3.8652
# 204의 평균 절대 오차: 1.1663
# 204의 R-squared: 0.9928
# 205의 평균 제곱 오차: 2.1278
# 205의 평균 절대 오차: 0.9313
# 205의 R-squared: 0.9960
# 206의 평균 제곱 오차: 1.9620
# 206의 평균 절대 오차: 0.8468
# 206의 R-squared: 0.9963
# 207의 평균 제곱 오차: 1.1199
# 207의 평균 절대 오차: 0.7589
# 207의 R-squared: 0.9979
# 208의 평균 제곱 오차: 1.8943
# 208의 평균 절대 오차: 0.9560
# 208의 R-squared: 0.9965
# 209의 평균 제곱 오차: 2.8237
# 209의 평균 절대 오차: 0.9984
# 209의 R-squared: 0.9947
# 210의 평균 제곱 오차: 1.7336
# 210의 평균 절대 오차: 0.7481
# 210의 R-squared: 0.9968
# 211의 평균 제곱 오차: 5.3199
# 211의 평균 절대 오차: 1.5615
# 211의 R-squared: 0.9901
# 212의 평균 제곱 오차: 2.9603
# 212의 평균 절대 오차: 1.1147
# 212의 R-squared: 0.9945
# 213의 평균 제곱 오차: 2.7743
# 213의 평균 절대 오차: 0.9427
# 213의 R-squared: 0.9948
# 214의 평균 제곱 오차: 1.8990
# 214의 평균 절대 오차: 0.9403
# 214의 R-squared: 0.9965
# 215의 평균 제곱 오차: 0.8013
# 215의 평균 절대 오차: 0.7092
# 215의 R-squared: 0.9985
# 216의 평균 제곱 오차: 0.5801
# 216의 평균 절대 오차: 0.6381
# 216의 R-squared: 0.9989
# 217의 평균 제곱 오차: 0.9462
# 217의 평균 절대 오차: 0.6913
# 217의 R-squared: 0.9982
# 218의 평균 제곱 오차: 1.8191
# 218의 평균 절대 오차: 0.9235
# 218의 R-squared: 0.9966
# 219의 평균 제곱 오차: 1.7980
# 219의 평균 절대 오차: 0.8392
# 219의 R-squared: 0.9966
# 220의 평균 제곱 오차: 1.8267
# 220의 평균 절대 오차: 0.8373
# 220의 R-squared: 0.9966
# 221의 평균 제곱 오차: 2.0555
# 221의 평균 절대 오차: 0.9546
# 221의 R-squared: 0.9962
# 222의 평균 제곱 오차: 1.4255
# 222의 평균 절대 오차: 0.8952
# 222의 R-squared: 0.9973
# 223의 평균 제곱 오차: 0.7524
# 223의 평균 절대 오차: 0.6561
# 223의 R-squared: 0.9986
# 224의 평균 제곱 오차: 1.2671
# 224의 평균 절대 오차: 0.8506
# 224의 R-squared: 0.9976
# 225의 평균 제곱 오차: 1.8083
# 225의 평균 절대 오차: 0.7794
# 225의 R-squared: 0.9966
# 226의 평균 제곱 오차: 1.9110
# 226의 평균 절대 오차: 0.9414
# 226의 R-squared: 0.9964
# 227의 평균 제곱 오차: 2.1059
# 227의 평균 절대 오차: 1.0311
# 227의 R-squared: 0.9961
# 228의 평균 제곱 오차: 1.1027
# 228의 평균 절대 오차: 0.7872
# 228의 R-squared: 0.9979
# 229의 평균 제곱 오차: 1.1632
# 229의 평균 절대 오차: 0.8037
# 229의 R-squared: 0.9978
# 230의 평균 제곱 오차: 1.1850
# 230의 평균 절대 오차: 0.8032
# 230의 R-squared: 0.9978
# 231의 평균 제곱 오차: 1.9755
# 231의 평균 절대 오차: 0.9608
# 231의 R-squared: 0.9963
# 232의 평균 제곱 오차: 2.8122
# 232의 평균 절대 오차: 1.0177
# 232의 R-squared: 0.9948
# 233의 평균 제곱 오차: 2.8513
# 233의 평균 절대 오차: 1.0495
# 233의 R-squared: 0.9947
# 234의 평균 제곱 오차: 2.0377
# 234의 평균 절대 오차: 0.9667
# 234의 R-squared: 0.9962
# 235의 평균 제곱 오차: 2.8656
# 235의 평균 절대 오차: 0.9940
# 235의 R-squared: 0.9947
# 236의 평균 제곱 오차: 2.0816
# 236의 평균 절대 오차: 0.9810
# 236의 R-squared: 0.9961
# 237의 평균 제곱 오차: 2.2234
# 237의 평균 절대 오차: 1.0315
# 237의 R-squared: 0.9959
# 238의 평균 제곱 오차: 3.0928
# 238의 평균 절대 오차: 1.0746
# 238의 R-squared: 0.9942
# 239의 평균 제곱 오차: 1.7482
# 239의 평균 절대 오차: 0.8234
# 239의 R-squared: 0.9967
# 240의 평균 제곱 오차: 2.2640
# 240의 평균 절대 오차: 0.9537
# 240의 R-squared: 0.9958
# 241의 평균 제곱 오차: 1.7627
# 241의 평균 절대 오차: 0.9427
# 241의 R-squared: 0.9967
# 242의 평균 제곱 오차: 2.1398
# 242의 평균 절대 오차: 0.9482
# 242의 R-squared: 0.9960
# 243의 평균 제곱 오차: 3.3485
# 243의 평균 절대 오차: 1.2656
# 243의 R-squared: 0.9938
# 244의 평균 제곱 오차: 2.3729
# 244의 평균 절대 오차: 1.0066
# 244의 R-squared: 0.9956
# 245의 평균 제곱 오차: 2.5895
# 245의 평균 절대 오차: 1.1173
# 245의 R-squared: 0.9952
# 246의 평균 제곱 오차: 3.0156
# 246의 평균 절대 오차: 1.0820
# 246의 R-squared: 0.9944
# 247의 평균 제곱 오차: 1.1790
# 247의 평균 절대 오차: 0.7518
# 247의 R-squared: 0.9978
# 248의 평균 제곱 오차: 0.9774
# 248의 평균 절대 오차: 0.7916
# 248의 R-squared: 0.9982
# 249의 평균 제곱 오차: 2.0574
# 249의 평균 절대 오차: 0.9347
# 249의 R-squared: 0.9962
# 250의 평균 제곱 오차: 1.1743
# 250의 평균 절대 오차: 0.7035
# 250의 R-squared: 0.9978
# 251의 평균 제곱 오차: 1.8653
# 251의 평균 절대 오차: 0.8824
# 251의 R-squared: 0.9965
# 252의 평균 제곱 오차: 2.0222
# 252의 평균 절대 오차: 0.9776
# 252의 R-squared: 0.9962
# 253의 평균 제곱 오차: 1.2370
# 253의 평균 절대 오차: 0.8690
# 253의 R-squared: 0.9977
# 254의 평균 제곱 오차: 1.4153
# 254의 평균 절대 오차: 0.7698
# 254의 R-squared: 0.9974
# 255의 평균 제곱 오차: 1.4142
# 255의 평균 절대 오차: 0.8615
# 255의 R-squared: 0.9974
# 256의 평균 제곱 오차: 2.1167
# 256의 평균 절대 오차: 0.9471
# 256의 R-squared: 0.9961
# 257의 평균 제곱 오차: 1.4347
# 257의 평균 절대 오차: 0.7262
# 257의 R-squared: 0.9973
# 258의 평균 제곱 오차: 1.2195
# 258의 평균 절대 오차: 0.8327
# 258의 R-squared: 0.9977
# 259의 평균 제곱 오차: 1.2054
# 259의 평균 절대 오차: 0.7141
# 259의 R-squared: 0.9978
# 260의 평균 제곱 오차: 1.3020
# 260의 평균 절대 오차: 0.8012
# 260의 R-squared: 0.9976
# 261의 평균 제곱 오차: 1.3213
# 261의 평균 절대 오차: 0.8309
# 261의 R-squared: 0.9975
# 262의 평균 제곱 오차: 0.7569
# 262의 평균 절대 오차: 0.6315
# 262의 R-squared: 0.9986
# 263의 평균 제곱 오차: 1.1050
# 263의 평균 절대 오차: 0.6730
# 263의 R-squared: 0.9979
# 264의 평균 제곱 오차: 1.4043
# 264의 평균 절대 오차: 0.8684
# 264의 R-squared: 0.9974
# 265의 평균 제곱 오차: 0.6694
# 265의 평균 절대 오차: 0.6814
# 265의 R-squared: 0.9988
# 266의 평균 제곱 오차: 1.8567
# 266의 평균 절대 오차: 0.9430
# 266의 R-squared: 0.9965
# 267의 평균 제곱 오차: 0.9432
# 267의 평균 절대 오차: 0.7054
# 267의 R-squared: 0.9982
# 268의 평균 제곱 오차: 1.3528
# 268의 평균 절대 오차: 0.7368
# 268의 R-squared: 0.9975
# 269의 평균 제곱 오차: 1.1781
# 269의 평균 절대 오차: 0.7112
# 269의 R-squared: 0.9978
# 270의 평균 제곱 오차: 2.0296
# 270의 평균 절대 오차: 0.9872
# 270의 R-squared: 0.9962
# 271의 평균 제곱 오차: 1.4410
# 271의 평균 절대 오차: 0.9499
# 271의 R-squared: 0.9973
# 272의 평균 제곱 오차: 1.4275
# 272의 평균 절대 오차: 0.8041
# 272의 R-squared: 0.9973
# 273의 평균 제곱 오차: 1.3256
# 273의 평균 절대 오차: 0.8782
# 273의 R-squared: 0.9975
# 274의 평균 제곱 오차: 1.3133
# 274의 평균 절대 오차: 0.8110
# 274의 R-squared: 0.9976
# 275의 평균 제곱 오차: 0.7508
# 275의 평균 절대 오차: 0.7262
# 275의 R-squared: 0.9986
# 276의 평균 제곱 오차: 1.3652
# 276의 평균 절대 오차: 0.8180
# 276의 R-squared: 0.9975
# 277의 평균 제곱 오차: 1.0859
# 277의 평균 절대 오차: 0.6400
# 277의 R-squared: 0.9980
# 278의 평균 제곱 오차: 1.0820
# 278의 평균 절대 오차: 0.7189
# 278의 R-squared: 0.9980
# 279의 평균 제곱 오차: 0.6277
# 279의 평균 절대 오차: 0.5985
# 279의 R-squared: 0.9988
# 280의 평균 제곱 오차: 1.9658
# 280의 평균 절대 오차: 0.9159
# 280의 R-squared: 0.9963
# 281의 평균 제곱 오차: 2.0085
# 281의 평균 절대 오차: 0.8275
# 281의 R-squared: 0.9963
# 282의 평균 제곱 오차: 2.1404
# 282의 평균 절대 오차: 1.0296
# 282의 R-squared: 0.9960
# 283의 평균 제곱 오차: 1.3718
# 283의 평균 절대 오차: 0.8812
# 283의 R-squared: 0.9974
# 284의 평균 제곱 오차: 1.2786
# 284의 평균 절대 오차: 0.8398
# 284의 R-squared: 0.9976
# 285의 평균 제곱 오차: 0.6921
# 285의 평균 절대 오차: 0.6437
# 285의 R-squared: 0.9987
# 286의 평균 제곱 오차: 2.3381
# 286의 평균 절대 오차: 0.9708
# 286의 R-squared: 0.9956
# 287의 평균 제곱 오차: 1.6142
# 287의 평균 절대 오차: 0.9696
# 287의 R-squared: 0.9970
# 288의 평균 제곱 오차: 1.3664
# 288의 평균 절대 오차: 0.8073
# 288의 R-squared: 0.9975
# 289의 평균 제곱 오차: 1.5291
# 289의 평균 절대 오차: 0.9113
# 289의 R-squared: 0.9971
# 290의 평균 제곱 오차: 1.0897
# 290의 평균 절대 오차: 0.6887
# 290의 R-squared: 0.9980
# 291의 평균 제곱 오차: 0.9493
# 291의 평균 절대 오차: 0.7597
# 291의 R-squared: 0.9982
# 292의 평균 제곱 오차: 1.9735
# 292의 평균 절대 오차: 0.9574
# 292의 R-squared: 0.9963
# 293의 평균 제곱 오차: 2.2703
# 293의 평균 절대 오차: 1.0326
# 293의 R-squared: 0.9958
# 294의 평균 제곱 오차: 2.0360
# 294의 평균 절대 오차: 0.8560
# 294의 R-squared: 0.9962
# 295의 평균 제곱 오차: 2.2742
# 295의 평균 절대 오차: 0.9605
# 295의 R-squared: 0.9958
# 296의 평균 제곱 오차: 1.2295
# 296의 평균 절대 오차: 0.7324
# 296의 R-squared: 0.9977
# 297의 평균 제곱 오차: 1.4373
# 297의 평균 절대 오차: 0.9295
# 297의 R-squared: 0.9973
# 298의 평균 제곱 오차: 1.7685
# 298의 평균 절대 오차: 0.9162
# 298의 R-squared: 0.9967
# 299의 평균 제곱 오차: 1.3269
# 299의 평균 절대 오차: 0.7043
# 299의 R-squared: 0.9975
# 300의 평균 제곱 오차: 1.3122
# 300의 평균 절대 오차: 0.7610
# 300의 R-squared: 0.9976

# %%
print(f"가장 작은 MSE: {test_min_mse}")
print(f"가장 작은 MAE: {test_min_mae}")
print(f"가장 큰 R-squared: {test_max_r2}")
print(f"가장 작은 MSE에 해당하는 파일 번호: {test_min_file_number}")
# Out:
# 가장 작은 MSE: 0.5206389820181657
# 가장 작은 MAE: 0.5634304034669313
# 가장 큰 R-squared: 0.9990290283124423
# 가장 작은 MSE에 해당하는 파일 번호: 192

# %%
# 새로운 이미지가 기존 이미지들과 일치하는지 확인
if test_min_mse - 0.5 < new_min_mse < test_min_mse and test_min_mae - 0.4 < new_min_mae < test_min_mae and new_max_r2 - 0.1 < test_max_r2 <= new_max_r2:
    print("새로운 이미지가 일치합니다.")
else:
    print("새로운 이미지가 일치하지 않습니다.")
# Out:
# 새로운 이미지가 일치합니다.
